# %%
import os
import subprocess
import itertools
import time
import torch

import numpy as np
import matplotlib.pyplot as plt

# analysis of Hessian
# !git clone https://github.com/amirgholami/PyHessian.git
import sys
sys.path.append('/content/PyHessian/')



# folder to save
base_path = 'results_FC_scales'

if not os.path.exists(base_path):
    os.makedirs(base_path)

# server setup
# launcher = "srun --nodes=1 --gres=gpu:1 --time=40:00:00 --mem=60G" # THIS IS AN EXAMPLE!!!

# experimental setup
# width = [4, 8, 16, 32, 64, 128, 256, 512, 1024]
# depth = [2, 3, 4, 5, 6, 7, 8, 9, 10]
# seeds = list(range(3))
# dataset = ['mnist', 'cifar10']
# loss = ['NLL','linear_hinge']
# dataset = ['mnist']
# model = ['fc']
w = 4
dep = 2
s = 0
l = 'NLL'
d = 'cifar10'
m = 'alexnet'

iter = 20000
eval_freq = 100 # don't vary it; keep it the same as in the code
close_check_lb = 900
close_check_hb = 2000
close_check_freq = 10 # set to eval_freq to remove the finer sampling 
                      # of certain iteration regions [close_check_lb, close_check_hb]
eval_Hessian_freq = 5000
# grid = itertools.product(width, depth, seeds, dataset, loss, model)

processes = []
# for w, dep, s, d, l, m in grid:

save_dir = base_path + '/{}_{:04d}_{:02d}_{}_{}_{}'.format(dep, w, s, d, l, m)
if os.path.exists(save_dir):
    # folder created only at the end when all is done!
    print('folder already exists, quitting')
    # continue

# cmd = launcher + ' '
cmd = 'python main.py '
cmd += '--save_dir {} '.format(save_dir)
if m == 'fc':
  cmd += '--width {} '.format(w)
elif m == 'alexnet':
  cmd += '--scale {} '.format(w)
cmd += '--depth {} '.format(dep)
cmd += '--seed {} '.format(s)
cmd += '--dataset {} '.format(d)
cmd += '--model {} '.format(m)
cmd += '--lr {} '.format('0.1')
cmd += '--lr_schedule '
cmd += '--iterations {} '.format(iter)
cmd += '--eval_freq {} '.format(eval_freq)
cmd += '--close_check_lb {} '.format(close_check_lb)
cmd += '--close_check_hb {} '.format(close_check_hb)
cmd += '--close_check_freq {} '.format(close_check_freq)
cmd += '--eval_Hessian_freq {} '.format(eval_Hessian_freq)
# cmd += '--print_freq {} '.format(1), # dbg
# cmd += '--verbose '

# print(cmd)

f = open(save_dir + '.log', 'w')

print(cmd)
# subprocess.Popen(cmd.split(), stdout=f, stderr=f)#.wait()
# Out:
# fatal: destination path 'PyHessian' already exists and is not an empty directory.
# folder already exists, quitting
# python main.py --save_dir results_FC_scales/2_0004_00_cifar10_NLL_alexnet --scale 4 --depth 2 --seed 0 --dataset cifar10 --model alexnet --lr 0.1 --lr_schedule --iterations 20000 --eval_freq 100 --close_check_lb 900 --close_check_hb 2000 --close_check_freq 10 --eval_Hessian_freq 5000

# %%
# !python main.py --save_dir results_FC_scales/2_0004_00_cifar10_NLL_alexnet --scale 4 --depth 2 --seed 0 --dataset cifar10 --model alexnet --lr 0.1 --lr_schedule --iterations 20000 --eval_freq 100 --close_check_lb 900 --close_check_hb 2000 --close_check_freq 10 --eval_Hessian_freq 5000
# Out:
# Namespace(batch_size_eval=100, batch_size_train=100, close_check_freq=10, close_check_hb=2000, close_check_lb=900, criterion='NLL', dataset='cifar10', depth=2, device=device(type='cpu'), double=False, eval_Hessian_freq=5000, eval_freq=100, iterations=20000, lr=0.1, lr_schedule=True, model='alexnet', mom=0, no_cuda=False, path='./data', print_freq=100, save_dir='results_FC_scales/2_0004_00_cifar10_NLL_alexnet', scale=4, seed=0, use_cuda=False, verbose=False, wd=0, width=100)
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([1, 4, 1, 1])
# 4
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 4, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(4, 4, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=4, out_features=12, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=12, out_features=12, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=12, out_features=10, bias=True)
#   )
# )
# [2.311556960105896, 10.0, 0.631106436252594]
# [2.311563832759857, 10.0, 0.5809732675552368]
# [2.311556960105896, 10.0, 0.631106436252594]
# [0, 2.3133890628814697, 5.0]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:154: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# checking Hessian
# Folder already exists, beware of overriding old data!
# [2.3036002178192136, 10.0, 0.6363953948020935]
# [2.303605272769928, 10.0, 0.5884940028190613]
# [2.3036002178192136, 10.0, 0.6363953948020935]
# [100, 2.296644926071167, 14.0]
# Folder already exists, beware of overriding old data!
# [2.302577022075653, 10.0, 0.6378194093704224]
# [2.3025820374488832, 10.0, 0.5912060737609863]
# [2.302577022075653, 10.0, 0.6378194093704224]
# [200, 2.3035097122192383, 11.0]
# Folder already exists, beware of overriding old data!
# [2.302872926235199, 10.0, 0.6466032862663269]
# [2.302875607013702, 10.0, 0.5892050266265869]
# [2.302872926235199, 10.0, 0.6466032862663269]
# [300, 2.301457405090332, 13.0]
# Folder already exists, beware of overriding old data!
# [2.302437846660614, 10.068, 0.6474414467811584]
# [2.3024392032623293, 10.08, 0.5937969088554382]
# [2.302437846660614, 10.068, 0.6474414467811584]
# [400, 2.310482978820801, 5.0]
# Folder already exists, beware of overriding old data!
# [2.302512291431427, 10.002, 0.6522475481033325]
# [2.3025143790245055, 10.0, 0.6028594374656677]
# [2.302512291431427, 10.002, 0.6522475481033325]
# [500, 2.305413007736206, 8.0]
# Folder already exists, beware of overriding old data!
# [2.302535702228546, 10.0, 0.6583185195922852]
# [2.3025396513938903, 10.0, 0.612583339214325]
# [2.302535702228546, 10.0, 0.6583185195922852]
# [600, 2.300006628036499, 5.0]
# Folder already exists, beware of overriding old data!
# [2.3019119539260866, 10.0, 0.6610051989555359]
# [2.3019191360473634, 10.0, 0.6108687520027161]
# [2.3019119539260866, 10.0, 0.6610051989555359]
# [700, 2.303797721862793, 7.0]
# Folder already exists, beware of overriding old data!
# [2.3016231527328492, 13.292, 0.6636277437210083]
# [2.3016399908065797, 13.4, 0.6028526425361633]
# [2.3016231527328492, 13.292, 0.6636277437210083]
# [800, 2.2941629886627197, 18.0]
# Folder already exists, beware of overriding old data!
# [2.2999420595169067, 12.768, 0.6614872813224792]
# [2.2999759459495546, 12.64, 0.5964263081550598]
# [2.2999420595169067, 12.768, 0.6614872813224792]
# [900, 2.3030331134796143, 7.0]
# Folder already exists, beware of overriding old data!
# [2.29987047958374, 13.444, 0.6626172661781311]
# [2.2999047374725343, 13.32, 0.5954640507698059]
# [1.951027319431305, 20.0, 0.8705887794494629]
# [1.9549634459018708, 19.564, 0.958329975605011]
# [2200, 2.1832616329193115, 20.0]
# Folder already exists, beware of overriding old data!
# [1.976408697128296, 18.426, 0.9540929198265076]
# [1.9728817677497863, 18.44, 0.9061343669891357]
# [1.976408697128296, 18.426, 0.9540929198265076]
# [2300, 1.9494322538375854, 26.0]
# Folder already exists, beware of overriding old data!
# [1.960830051422119, 19.052, 0.9834993481636047]
# [1.9574490535259246, 19.39, 0.9247316718101501]
# [1.960830051422119, 19.052, 0.9834993481636047]
# [2400, 2.065018653869629, 19.0]
# Folder already exists, beware of overriding old data!
# [1.9751016502380372, 20.884, 0.9533907771110535]
# [1.9728479337692262, 20.99, 0.9008034467697144]
# [1.9751016502380372, 20.884, 0.9533907771110535]
# [2500, 2.06687331199646, 10.0]
# Folder already exists, beware of overriding old data!
# [1.9513464422225952, 18.35, 0.9591037034988403]
# [1.948883285522461, 18.23, 0.9140597581863403]
# [1.9513464422225952, 18.35, 0.9591037034988403]
# [2600, 2.0533158779144287, 18.0]
# Folder already exists, beware of overriding old data!
# [1.9493095712661743, 18.862, 0.9449393153190613]
# [1.9498126661777497, 18.78, 0.8986068367958069]
# [1.9493095712661743, 18.862, 0.9449393153190613]
# [2700, 2.020423650741577, 24.0]
# Folder already exists, beware of overriding old data!
# [1.9234704089164734, 19.996, 0.9646896123886108]
# [1.9226943111419679, 20.0, 0.9111859202384949]
# [1.9234704089164734, 19.996, 0.9646896123886108]
# [2800, 1.9673923254013062, 19.0]
# Folder already exists, beware of overriding old data!
# [1.9273410232067107, 19.554, 0.9471897482872009]
# [1.9262791657447815, 19.94, 0.8974339962005615]
# [1.9273410232067107, 19.554, 0.9471897482872009]
# [2900, 1.9360827207565308, 29.0]
# Folder already exists, beware of overriding old data!
# [1.9245008840560913, 20.184, 1.0116374492645264]
# [1.9247192680835723, 20.34, 0.9495988488197327]
# [1.9245008840560913, 20.184, 1.0116374492645264]
# [3000, 2.0503382682800293, 11.0]
# Folder already exists, beware of overriding old data!
# [1.9574425551891328, 18.2, 0.9949123859405518]
# [1.9554907119274139, 18.28, 0.9330272078514099]
# [1.9574425551891328, 18.2, 0.9949123859405518]
# [3100, 2.1369330883026123, 17.0]
# Folder already exists, beware of overriding old data!
# [1.9108389437198638, 19.03, 1.0013121366500854]
# [1.911611226797104, 19.21, 0.9557620882987976]
# [1.9108389437198638, 19.03, 1.0013121366500854]
# [3200, 2.0537211894989014, 19.0]
# Folder already exists, beware of overriding old data!
# [1.9097302179336548, 20.232, 0.9797693490982056]
# [1.9112443351745605, 20.25, 0.9021409153938293]
# [1.9097302179336548, 20.232, 0.9797693490982056]
# [3300, 1.880083441734314, 25.0]
# Folder already exists, beware of overriding old data!
# [1.9178565962314607, 19.644, 0.9302813410758972]
# [1.9195256996154786, 19.65, 0.8652602434158325]
# [1.9178565962314607, 19.644, 0.9302813410758972]
# [3400, 1.9597558975219727, 25.0]
# Folder already exists, beware of overriding old data!
# [1.9276467657089233, 20.178, 0.9679665565490723]
# [1.9302857732772827, 20.2, 0.9175857305526733]
# [1.9276467657089233, 20.178, 0.9679665565490723]
# [3500, 2.0414583683013916, 13.0]
# Folder already exists, beware of overriding old data!
# [1.926818589448929, 19.55, 0.9263839721679688]
# [1.9278130650520324, 19.69, 0.8452818393707275]
# [1.926818589448929, 19.55, 0.9263839721679688]
# [3600, 2.059161901473999, 21.0]
# Folder already exists, beware of overriding old data!
# [1.9199109573364257, 18.748, 0.9706255197525024]
# [1.920671762228012, 18.82, 0.8940449357032776]
# [1.9199109573364257, 18.748, 0.9706255197525024]
# [3700, 2.0052826404571533, 24.0]
# Folder already exists, beware of overriding old data!
# [1.9161030676364899, 19.436, 0.9369802474975586]
# [1.9169935441017152, 19.58, 0.860828161239624]
# [1.9161030676364899, 19.436, 0.9369802474975586]
# [3800, 1.8979510068893433, 20.0]
# Folder already exists, beware of overriding old data!
# [1.9264312002658843, 18.636, 0.9707513451576233]
# [1.9266567254066467, 18.89, 0.8997552394866943]
# [1.9264312002658843, 18.636, 0.9707513451576233]
# [3900, 1.975711464881897, 14.0]
# Folder already exists, beware of overriding old data!
# [1.9089482760429382, 20.126, 0.9894844889640808]
# [1.911964135169983, 20.2, 0.8812445998191833]
# [1.9089482760429382, 20.126, 0.9894844889640808]
# [4000, 2.092251777648926, 15.0]
# Folder already exists, beware of overriding old data!
# [1.899653740167618, 20.608, 0.9649179577827454]
# [1.9013336300849915, 20.69, 0.9020830392837524]
# [1.899653740167618, 20.608, 0.9649179577827454]
# [4100, 2.0378687381744385, 17.0]
# Folder already exists, beware of overriding old data!
# [1.9036346611976624, 19.054, 0.9339268803596497]
# [1.9051703608036041, 19.02, 0.8672865629196167]
# [1.9036346611976624, 19.054, 0.9339268803596497]
# [4200, 2.1117467880249023, 18.0]
# Folder already exists, beware of overriding old data!
# [1.90930025100708, 20.916, 0.9520489573478699]
# [1.9107555758953094, 20.62, 0.8896002173423767]
# [1.90930025100708, 20.916, 0.9520489573478699]
# [4300, 1.8470631837844849, 28.0]
# Folder already exists, beware of overriding old data!
# [1.9191406598091125, 19.232, 0.8771591186523438]
# [1.9201824986934661, 19.73, 0.844517707824707]
# [1.9191406598091125, 19.232, 0.8771591186523438]
# [4400, 1.9902557134628296, 17.0]
# Folder already exists, beware of overriding old data!
# [1.923589374065399, 19.956, 0.9592160582542419]
# [1.9246476149559022, 20.18, 0.8859753608703613]
# [1.923589374065399, 19.956, 0.9592160582542419]
# [4500, 2.0235023498535156, 13.0]
# Folder already exists, beware of overriding old data!
# [1.9247791786193849, 18.572, 0.9479237794876099]
# [1.92608274102211, 18.47, 0.8755429983139038]
# [1.9247791786193849, 18.572, 0.9479237794876099]
# [4600, 1.996717929840088, 25.0]
# Folder already exists, beware of overriding old data!
# [1.9108832321166993, 19.4, 0.9879371523857117]
# [1.9125537824630738, 19.4, 0.8761152625083923]
# [1.9108832321166993, 19.4, 0.9879371523857117]
# [4700, 2.007082939147949, 22.0]
# Folder already exists, beware of overriding old data!
# [1.9124421002864838, 20.312, 0.9641287922859192]
# [1.9125476598739624, 20.55, 0.9124078154563904]
# [1.9124421002864838, 20.312, 0.9641287922859192]
# [4800, 1.8949341773986816, 26.0]
# Folder already exists, beware of overriding old data!
# [1.9245644800662995, 18.876, 0.9440265893936157]
# [1.9247196996212006, 18.98, 0.8642479181289673]
# [1.9245644800662995, 18.876, 0.9440265893936157]
# [4900, 1.9303791522979736, 20.0]
# Folder already exists, beware of overriding old data!
# [1.9305965027809142, 19.508, 0.9033280611038208]
# [1.9305919432640075, 19.43, 0.8245492577552795]
# [1.9305965027809142, 19.508, 0.9033280611038208]
# [5000, 2.0792174339294434, 13.0]
# checking Hessian
# Folder already exists, beware of overriding old data!
# [1.9281261465549469, 19.144, 0.9351945519447327]
# [1.9298593282699585, 19.11, 0.86344313621521]
# [1.9281261465549469, 19.144, 0.9351945519447327]
# [5100, 2.0880303382873535, 15.0]
# Folder already exists, beware of overriding old data!
# [1.9139777207374573, 19.602, 0.9251328706741333]
# [1.9147501111030578, 19.63, 0.8287152647972107]
# [1.9139777207374573, 19.602, 0.9251328706741333]
# [5200, 2.008526086807251, 22.0]
# Folder already exists, beware of overriding old data!
# [1.9494996678829193, 19.298, 0.9705774784088135]
# [1.9491080272197723, 19.68, 0.8861371874809265]
# [1.9494996678829193, 19.298, 0.9705774784088135]
# [5300, 1.9663004875183105, 22.0]
# Folder already exists, beware of overriding old data!
# [1.9383978147506713, 18.13, 0.8809815645217896]
# [1.938850576877594, 18.17, 0.7828832268714905]
# [1.9383978147506713, 18.13, 0.8809815645217896]
# [5400, 1.9163975715637207, 16.0]
# Folder already exists, beware of overriding old data!
# [1.9182620770931245, 18.882, 0.9156804084777832]
# [1.918817708492279, 18.94, 0.8287518620491028]
# [1.9182620770931245, 18.882, 0.9156804084777832]
# [5500, 2.0509536266326904, 16.0]
# Folder already exists, beware of overriding old data!
# [1.9368854422569275, 18.276, 0.910014271736145]
# [1.9394615733623504, 18.05, 0.8154308795928955]
# [1.9368854422569275, 18.276, 0.910014271736145]
# [5600, 2.0129201412200928, 18.0]
# Folder already exists, beware of overriding old data!
# [1.9305732414722443, 19.652, 0.8842036724090576]
# [1.9313858091831206, 19.54, 0.8047025203704834]
# [1.9305732414722443, 19.652, 0.8842036724090576]
# [5700, 2.0581722259521484, 19.0]
# Folder already exists, beware of overriding old data!
# [1.9330697803497314, 18.956, 0.9018720984458923]
# [1.9337837719917297, 19.13, 0.7993741035461426]
# [1.9330697803497314, 18.956, 0.9018720984458923]
# [5800, 1.901633858680725, 27.0]
# Folder already exists, beware of overriding old data!
# [1.910422738313675, 19.736, 0.9138718843460083]
# [1.9114939260482788, 19.81, 0.830112636089325]
# [1.910422738313675, 19.736, 0.9138718843460083]
# [5900, 1.9040015935897827, 20.0]
# Folder already exists, beware of overriding old data!
# [1.9221182806491852, 18.13, 0.9161813855171204]
# [1.9250569188594817, 18.18, 0.8433083295822144]
# [1.9221182806491852, 18.13, 0.9161813855171204]
# [6000, 2.022179365158081, 12.0]
# Folder already exists, beware of overriding old data!
# [1.9221394426822662, 19.152, 0.9143648147583008]
# [1.9233147275447846, 18.95, 0.8560317754745483]
# [1.9221394426822662, 19.152, 0.9143648147583008]
# [6100, 1.9758427143096924, 19.0]
# Folder already exists, beware of overriding old data!
# [1.9357639119625092, 19.198, 0.9399252533912659]
# [1.935792944431305, 19.15, 0.8661327958106995]
# [1.9357639119625092, 19.198, 0.9399252533912659]
# [6200, 2.0824923515319824, 16.0]
# Folder already exists, beware of overriding old data!
# [1.9278550024032592, 18.936, 0.9401634931564331]
# [1.9275160324573517, 19.02, 0.8742870092391968]
# [1.9278550024032592, 18.936, 0.9401634931564331]
# [6300, 1.8713853359222412, 27.0]
# Folder already exists, beware of overriding old data!
# [1.928516536951065, 18.384, 0.9569706916809082]
# [1.9296093380451202, 18.62, 0.8654537796974182]
# [1.928516536951065, 18.384, 0.9569706916809082]
# [6400, 1.9955967664718628, 19.0]
# Folder already exists, beware of overriding old data!
# [1.9145597007274628, 19.37, 0.9468884468078613]
# [1.9162742400169372, 19.43, 0.8833735585212708]
# [1.9145597007274628, 19.37, 0.9468884468078613]
# [6500, 2.065887928009033, 14.0]
# Folder already exists, beware of overriding old data!
# [1.9264579396247863, 19.194, 0.9517867565155029]
# [1.9283026480674743, 19.14, 0.8615520000457764]
# [1.9264579396247863, 19.194, 0.9517867565155029]
# [6600, 2.0280864238739014, 23.0]
# Folder already exists, beware of overriding old data!
# [1.9004139001369476, 19.49, 0.9610210657119751]
# [1.9028110897541046, 19.58, 0.8846684694290161]
# [1.9004139001369476, 19.49, 0.9610210657119751]
# [6700, 2.0311553478240967, 15.0]
# Folder already exists, beware of overriding old data!
# [1.90656143283844, 18.802, 0.9381974339485168]
# [1.9063964343070985, 18.96, 0.8743524551391602]
# [1.90656143283844, 18.802, 0.9381974339485168]
# [6800, 1.8879754543304443, 30.0]
# Folder already exists, beware of overriding old data!
# [1.915124392747879, 19.508, 0.9322158694267273]
# [1.9155742919445038, 19.63, 0.8514852523803711]
# [1.915124392747879, 19.508, 0.9322158694267273]
# [6900, 1.9387811422348022, 22.0]
# Folder already exists, beware of overriding old data!
# [1.9088183181285858, 19.414, 0.9322186708450317]
# [1.9087043654918672, 19.53, 0.8547454476356506]
# [1.9088183181285858, 19.414, 0.9322186708450317]
# [7000, 2.017134666442871, 14.0]
# Folder already exists, beware of overriding old data!
# [1.9172665128707886, 19.234, 0.9470763802528381]
# [1.9168686735630036, 19.31, 0.8655154705047607]
# [1.9172665128707886, 19.234, 0.9470763802528381]
# [7100, 1.9745488166809082, 18.0]
# Folder already exists, beware of overriding old data!
# [1.9061353342533112, 20.392, 0.9260976314544678]
# [1.9065702486038207, 20.45, 0.8642699718475342]
# [1.9061353342533112, 20.392, 0.9260976314544678]
# [7200, 1.9944567680358887, 26.0]
# Folder already exists, beware of overriding old data!
# [1.9016503427028657, 19.772, 0.938075840473175]
# [1.9017483723163604, 19.84, 0.8849287033081055]
# [1.9016503427028657, 19.772, 0.938075840473175]
# [7300, 1.8984931707382202, 28.0]
# Folder already exists, beware of overriding old data!
# [1.9070640063285829, 19.818, 0.9397546648979187]
# [1.9074955356121064, 19.91, 0.8514360189437866]
# [1.9070640063285829, 19.818, 0.9397546648979187]
# [7400, 1.8843798637390137, 28.0]
# Folder already exists, beware of overriding old data!
# [1.8975914041996003, 20.128, 0.9254089593887329]
# [1.8987695634365083, 20.42, 0.8709108233451843]
# [1.8975914041996003, 20.128, 0.9254089593887329]
# [7500, 2.0618972778320312, 15.0]
# Folder already exists, beware of overriding old data!
# [1.9068186357021333, 19.808, 0.9353110194206238]
# [1.907544833421707, 20.08, 0.8559227585792542]
# [1.9068186357021333, 19.808, 0.9353110194206238]
# [7600, 1.9060004949569702, 36.0]
# Folder already exists, beware of overriding old data!
# [1.8961506958007812, 20.08, 0.9436264634132385]
# [1.8953869795799256, 19.91, 0.8624240159988403]
# [1.8961506958007812, 20.08, 0.9436264634132385]
# [7700, 2.0950820446014404, 17.0]
# Folder already exists, beware of overriding old data!
# [1.9004825670719148, 19.464, 0.9459086060523987]
# [1.9006872808933257, 19.55, 0.8914691805839539]
# [1.9004825670719148, 19.464, 0.9459086060523987]
# [7800, 1.8347117900848389, 29.0]
# Folder already exists, beware of overriding old data!
# [1.9028927512168885, 19.126, 0.9469792246818542]
# [1.9047091507911682, 19.03, 0.8777021765708923]
# [1.9028927512168885, 19.126, 0.9469792246818542]
# [7900, 1.971303105354309, 17.0]
# Folder already exists, beware of overriding old data!
# [1.896690099477768, 20.142, 0.9374249577522278]
# [1.8971733939647675, 20.07, 0.8675863146781921]
# [1.896690099477768, 20.142, 0.9374249577522278]
# [8000, 2.0317749977111816, 15.0]
# Folder already exists, beware of overriding old data!
# [1.904760020494461, 19.15, 0.9438084363937378]
# [1.9045561230182648, 19.22, 0.8649156093597412]
# [1.904760020494461, 19.15, 0.9438084363937378]
# [8100, 1.9390654563903809, 27.0]
# Folder already exists, beware of overriding old data!
# [1.899768542289734, 20.184, 0.9408001899719238]
# [1.899757307767868, 20.18, 0.8768210411071777]
# [1.899768542289734, 20.184, 0.9408001899719238]
# [8200, 2.020697832107544, 21.0]
# Folder already exists, beware of overriding old data!
# [1.9099489650726318, 19.274, 0.9421632289886475]
# [1.9102338695526122, 19.15, 0.8693665266036987]
# [1.9099489650726318, 19.274, 0.9421632289886475]
# [8300, 1.866113543510437, 29.0]
# Folder already exists, beware of overriding old data!
# [1.9049759731292724, 19.73, 0.9341403245925903]
# [1.9045373547077178, 20.21, 0.8593941926956177]
# [1.9049759731292724, 19.73, 0.9341403245925903]
# [8400, 2.000826597213745, 19.0]
# Folder already exists, beware of overriding old data!
# [1.902152185678482, 20.062, 0.9349794983863831]
# [1.9020833230018617, 20.13, 0.8742236495018005]
# [1.902152185678482, 20.062, 0.9349794983863831]
# [8500, 1.9780125617980957, 17.0]
# Folder already exists, beware of overriding old data!
# [1.9109801008701324, 19.772, 0.9383352994918823]
# [1.911653733253479, 19.94, 0.8580433130264282]
# [1.9109801008701324, 19.772, 0.9383352994918823]
# [8600, 1.9837744235992432, 25.0]
# Folder already exists, beware of overriding old data!
# [1.8970368556976318, 19.804, 0.9519829154014587]
# [1.8970472884178162, 19.81, 0.8673805594444275]
# [1.8970368556976318, 19.804, 0.9519829154014587]
# [8700, 2.0547478199005127, 20.0]
# Folder already exists, beware of overriding old data!
# [1.9029286077022554, 18.562, 0.9381848573684692]
# [1.9025719857215881, 18.78, 0.8805944323539734]
# [1.9029286077022554, 18.562, 0.9381848573684692]
# [8800, 1.7929060459136963, 33.0]
# Folder already exists, beware of overriding old data!
# [1.9102658526897431, 18.936, 0.9403197169303894]
# [1.9104295730590821, 19.02, 0.8716760277748108]
# [1.9102658526897431, 18.936, 0.9403197169303894]
# [8900, 1.9786262512207031, 21.0]
# Folder already exists, beware of overriding old data!
# [1.9047368991374969, 19.238, 0.9633110761642456]
# [1.9052692306041719, 19.31, 0.8603636026382446]
# [1.9047368991374969, 19.238, 0.9633110761642456]
# [9000, 1.9955676794052124, 16.0]
# Folder already exists, beware of overriding old data!
# [1.9111939630508423, 19.506, 0.9515637159347534]
# [1.9131474697589874, 19.61, 0.8715629577636719]
# [1.9111939630508423, 19.506, 0.9515637159347534]
# [9100, 1.9518831968307495, 21.0]
# Folder already exists, beware of overriding old data!
# [1.9137362308502197, 19.474, 0.9523855447769165]
# [1.9135966074466706, 19.57, 0.8557663559913635]
# [1.9137362308502197, 19.474, 0.9523855447769165]
# [9200, 2.063926935195923, 16.0]
# Folder already exists, beware of overriding old data!
# [1.9157247698307038, 19.632, 0.9490931034088135]
# [1.9162681984901428, 19.62, 0.8817812204360962]
# [1.9157247698307038, 19.632, 0.9490931034088135]
# [9300, 1.8791390657424927, 30.0]
# Folder already exists, beware of overriding old data!
# [1.9091422581672668, 19.214, 0.9677047729492188]
# [1.9094827854633332, 19.44, 0.8675928115844727]
# [1.9091422581672668, 19.214, 0.9677047729492188]
# [9400, 2.0071327686309814, 11.0]
# Folder already exists, beware of overriding old data!
# [1.9012457888126373, 19.472, 0.9620482921600342]
# [1.902156275510788, 19.4, 0.8647205233573914]
# [1.9012457888126373, 19.472, 0.9620482921600342]
# [9500, 1.9995640516281128, 9.0]
# Folder already exists, beware of overriding old data!
# [1.8961399512290955, 19.588, 0.9407570362091064]
# [1.89760302901268, 19.59, 0.8708541393280029]
# [1.8961399512290955, 19.588, 0.9407570362091064]
# [9600, 1.8832858800888062, 22.0]
# Folder already exists, beware of overriding old data!
# [1.9067788851261138, 19.282, 0.9613519310951233]
# [1.9068395042419433, 19.27, 0.8466694355010986]
# [1.9067788851261138, 19.282, 0.9613519310951233]
# [9700, 2.038693904876709, 17.0]
# Folder already exists, beware of overriding old data!
# [1.8949659316539764, 19.372, 0.9409071803092957]
# [1.8952438056468963, 19.42, 0.8796282410621643]
# [1.8949659316539764, 19.372, 0.9409071803092957]
# [9800, 1.8685554265975952, 28.0]
# Folder already exists, beware of overriding old data!
# [1.9062120170593262, 18.672, 0.9179702997207642]
# [1.906947544813156, 18.62, 0.8618394136428833]
# [1.9062120170593262, 18.672, 0.9179702997207642]
# [9900, 1.9885809421539307, 17.0]
# Folder already exists, beware of overriding old data!
# [1.8736510486602784, 21.68, 0.9210673570632935]
# [1.874306310415268, 21.59, 0.8564211130142212]
# [1.8736510486602784, 21.68, 0.9210673570632935]
# [10000, 2.0102269649505615, 18.0]
# checking Hessian
# Folder already exists, beware of overriding old data!
# [1.9063849518299103, 19.008, 0.9366635680198669]
# [1.907388949394226, 18.87, 0.8598794341087341]
# [1.9063849518299103, 19.008, 0.9366635680198669]
# [10100, 1.9286019802093506, 27.0]
# Folder already exists, beware of overriding old data!
# [1.9032965204715728, 19.334, 0.926459789276123]
# [1.9045909392833709, 19.2, 0.8595564961433411]
# [1.9032965204715728, 19.334, 0.926459789276123]
# [10200, 2.074639320373535, 18.0]
# Folder already exists, beware of overriding old data!
# [1.8988828592300415, 19.762, 0.9548013806343079]
# [1.8995662701129914, 19.79, 0.8804877996444702]
# [1.8988828592300415, 19.762, 0.9548013806343079]
# [10300, 1.874369502067566, 29.0]
# Folder already exists, beware of overriding old data!
# [1.937238406419754, 18.558, 0.9063523411750793]
# [1.9373707711696624, 18.49, 0.8191763162612915]
# [1.937238406419754, 18.558, 0.9063523411750793]
# [10400, 1.998469352722168, 25.0]
# Folder already exists, beware of overriding old data!
# [1.9082774477005005, 19.502, 0.9286018013954163]
# [1.9094107401371003, 19.76, 0.8434432148933411]
# [1.9082774477005005, 19.502, 0.9286018013954163]
# [10500, 1.99031400680542, 20.0]
# Folder already exists, beware of overriding old data!
# [1.9085242869853973, 19.318, 0.9351504445075989]
# [1.9097787153720855, 19.24, 0.8679202198982239]
# [1.9085242869853973, 19.318, 0.9351504445075989]
# [10600, 1.925856113433838, 25.0]
# Folder already exists, beware of overriding old data!
# [1.9010078492164613, 19.472, 0.9384403228759766]
# [1.9008867561817169, 19.62, 0.8561563491821289]
# [1.9010078492164613, 19.472, 0.9384403228759766]
# [10700, 2.039155960083008, 16.0]
# Folder already exists, beware of overriding old data!
# [1.8989255380630494, 20.008, 0.9361149072647095]
# [1.8987509405612946, 20.32, 0.8741713762283325]
# [1.8989255380630494, 20.008, 0.9361149072647095]
# [10800, 1.7717753648757935, 38.0]
# Folder already exists, beware of overriding old data!
# [1.9128326494693757, 18.752, 0.9190364480018616]
# [1.913072135448456, 18.79, 0.841924250125885]
# [1.9128326494693757, 18.752, 0.9190364480018616]
# [10900, 2.013500213623047, 16.0]
# Folder already exists, beware of overriding old data!
# [1.8965208818912507, 19.774, 0.9261549711227417]
# [1.8971960544586182, 19.87, 0.8493427038192749]
# [1.8965208818912507, 19.774, 0.9261549711227417]
# [11000, 2.036444902420044, 13.0]
# Folder already exists, beware of overriding old data!
# [1.9097632274627685, 18.824, 0.9139043092727661]
# [1.9107368910312652, 18.75, 0.8514001369476318]
# [1.9097632274627685, 18.824, 0.9139043092727661]
# [11100, 1.9397326707839966, 21.0]
# Folder already exists, beware of overriding old data!
# [1.9081270923614502, 19.192, 0.910275936126709]
# [1.9092356824874879, 19.12, 0.8160066604614258]
# [1.9081270923614502, 19.192, 0.910275936126709]
# [11200, 2.0522871017456055, 24.0]
# Folder already exists, beware of overriding old data!
# [1.8895002267360688, 20.122, 0.9350787997245789]
# [1.8898912835121155, 20.34, 0.860560953617096]
# [1.8895002267360688, 20.122, 0.9350787997245789]
# [11300, 1.794435739517212, 35.0]
# Folder already exists, beware of overriding old data!
# [1.900564308643341, 19.14, 0.9278087019920349]
# [1.901009862422943, 19.49, 0.8470878601074219]
# [1.900564308643341, 19.14, 0.9278087019920349]
# [11400, 1.9318079948425293, 21.0]
# Folder already exists, beware of overriding old data!
# [1.905304303407669, 19.2, 0.9061945080757141]
# [1.9067520821094512, 19.29, 0.8257619142532349]
# [1.905304303407669, 19.2, 0.9061945080757141]
# [11500, 1.9730424880981445, 17.0]
# Folder already exists, beware of overriding old data!
# [1.9003303830623626, 20.606, 0.9392703175544739]
# [1.9004487705230713, 20.76, 0.8562405109405518]
# [1.9003303830623626, 20.606, 0.9392703175544739]
# [11600, 2.0325403213500977, 21.0]
# Folder already exists, beware of overriding old data!
# [1.9113668327331543, 19.554, 0.928176760673523]
# [1.9116895222663879, 19.39, 0.8516829013824463]
# [1.9113668327331543, 19.554, 0.928176760673523]
# [11700, 2.0856738090515137, 17.0]
# Folder already exists, beware of overriding old data!
# [1.9062903792858124, 19.46, 0.9564628601074219]
# [1.9068035280704498, 19.5, 0.8701798915863037]
# [1.9062903792858124, 19.46, 0.9564628601074219]
# [11800, 1.9038817882537842, 30.0]
# Folder already exists, beware of overriding old data!
# [1.9181090466976165, 18.472, 0.9362106919288635]
# [1.9183399653434754, 18.62, 0.8310741186141968]
# [1.9181090466976165, 18.472, 0.9362106919288635]
# [11900, 1.9667729139328003, 24.0]
# Folder already exists, beware of overriding old data!
# [1.9224799809455873, 19.582, 0.927172064781189]
# [1.9234608340263366, 19.77, 0.8436959981918335]
# [1.9224799809455873, 19.582, 0.927172064781189]
# [12000, 2.003316879272461, 14.0]
# Folder already exists, beware of overriding old data!
# [1.9041660113334655, 20.11, 0.944365918636322]
# [1.9045979809761047, 20.42, 0.8578656911849976]
# [1.9041660113334655, 20.11, 0.944365918636322]
# [12100, 1.9722158908843994, 19.0]
# Folder already exists, beware of overriding old data!
# [1.9114873185157777, 19.9, 0.962890625]
# [1.9120856249332427, 19.58, 0.8616117238998413]
# [1.9114873185157777, 19.9, 0.962890625]
# [12200, 2.067932367324829, 21.0]
# Folder already exists, beware of overriding old data!
# [1.900021550655365, 21.276, 0.9431156516075134]
# [1.9023178565502166, 21.11, 0.868286669254303]
# [1.900021550655365, 21.276, 0.9431156516075134]
# [12300, 1.7392364740371704, 29.0]
# Folder already exists, beware of overriding old data!
# [1.9241297233104706, 18.308, 0.9401729106903076]
# [1.9258757066726684, 18.28, 0.8527672290802002]
# [1.9241297233104706, 18.308, 0.9401729106903076]
# [12400, 1.9490584135055542, 19.0]
# Folder already exists, beware of overriding old data!
# [1.8874780526161195, 21.198, 0.9294650554656982]
# [1.8915721571445465, 21.13, 0.8746433258056641]
# [1.8874780526161195, 21.198, 0.9294650554656982]
# [12500, 2.023876905441284, 17.0]
# Folder already exists, beware of overriding old data!
# [1.9060339965820312, 19.37, 0.9579810500144958]
# [1.9083661675453185, 19.25, 0.8881428837776184]
# [1.9060339965820312, 19.37, 0.9579810500144958]
# [12600, 1.9464669227600098, 26.0]
# Folder already exists, beware of overriding old data!
# [1.890898353099823, 20.292, 0.9476467370986938]
# [1.8919506919384004, 20.43, 0.8791631460189819]
# [1.890898353099823, 20.292, 0.9476467370986938]
# [12700, 2.115473985671997, 23.0]
# Folder already exists, beware of overriding old data!
# [1.8950489332675935, 20.206, 0.9476544857025146]
# [1.8966612470149995, 20.29, 0.8865141272544861]
# [1.8950489332675935, 20.206, 0.9476544857025146]
# [12800, 1.8187452554702759, 30.0]
# Folder already exists, beware of overriding old data!
# [1.8985387427806855, 19.632, 0.9450861215591431]
# [1.8981842148303985, 19.96, 0.8680066466331482]
# [1.8985387427806855, 19.632, 0.9450861215591431]
# [12900, 1.8790900707244873, 26.0]
# Folder already exists, beware of overriding old data!
# [1.8919312567710878, 20.744, 0.9287420511245728]
# [1.8948324477672578, 20.5, 0.8615133166313171]
# [1.8919312567710878, 20.744, 0.9287420511245728]
# [13000, 1.9697470664978027, 17.0]
# Folder already exists, beware of overriding old data!
# [1.8916549034118653, 21.02, 0.9443132877349854]
# [1.8950644659996032, 20.74, 0.8736730813980103]
# [1.8916549034118653, 21.02, 0.9443132877349854]
# [13100, 1.9255768060684204, 31.0]
# Folder already exists, beware of overriding old data!
# [1.8875640635490418, 21.228, 0.9405418634414673]
# [1.891198043823242, 21.23, 0.8634708523750305]
# [1.8875640635490418, 21.228, 0.9405418634414673]
# [13200, 2.019728899002075, 18.0]
# Folder already exists, beware of overriding old data!
# [1.909026771068573, 19.766, 0.9418715834617615]
# [1.91211883187294, 19.76, 0.8670861124992371]
# [1.909026771068573, 19.766, 0.9418715834617615]
# [13300, 1.8318911790847778, 32.0]
# Folder already exists, beware of overriding old data!
# [1.8897565121650697, 19.894, 0.9546692371368408]
# [1.8925293850898743, 19.77, 0.8808675408363342]
# [1.8897565121650697, 19.894, 0.9546692371368408]
# [13400, 1.903151512145996, 20.0]
# Folder already exists, beware of overriding old data!
# [1.8778195083141327, 21.482, 0.9457136988639832]
# [1.8813419437408447, 21.45, 0.880103349685669]
# [1.8778195083141327, 21.482, 0.9457136988639832]
# [13500, 1.9935047626495361, 24.0]
# Folder already exists, beware of overriding old data!
# [1.8764050438404083, 21.114, 0.9523192644119263]
# [1.8790572917461394, 20.91, 0.8750986456871033]
# [1.8764050438404083, 21.114, 0.9523192644119263]
# [13600, 1.8861442804336548, 22.0]
# Folder already exists, beware of overriding old data!
# [1.8903490447998046, 21.032, 0.9574102163314819]
# [1.8926933324337005, 21.35, 0.8855594396591187]
# [1.8903490447998046, 21.032, 0.9574102163314819]
# [13700, 2.059603691101074, 21.0]
# Folder already exists, beware of overriding old data!
# [1.884101196050644, 21.414, 0.951191782951355]
# [1.8883947002887727, 21.43, 0.8850737810134888]
# [1.884101196050644, 21.414, 0.951191782951355]
# [13800, 1.8573755025863647, 31.0]
# Folder already exists, beware of overriding old data!
# [1.8880955538749695, 20.49, 0.9520887136459351]
# [1.8908869087696076, 20.65, 0.87669837474823]
# [1.8880955538749695, 20.49, 0.9520887136459351]
# [13900, 1.9117307662963867, 14.0]
# Folder already exists, beware of overriding old data!
# [1.8760056755542756, 21.998, 0.9539312124252319]
# [1.8783370113372804, 22.05, 0.8763741850852966]
# [1.8760056755542756, 21.998, 0.9539312124252319]
# [14000, 2.008437395095825, 16.0]
# Folder already exists, beware of overriding old data!
# [1.8713529982566834, 22.34, 0.9435975551605225]
# [1.8754639780521394, 22.19, 0.8799794912338257]
# [1.8713529982566834, 22.34, 0.9435975551605225]
# [14100, 1.9904437065124512, 18.0]
# Folder already exists, beware of overriding old data!
# [1.884712479352951, 20.764, 0.9516996145248413]
# [1.887795752286911, 20.87, 0.8931266665458679]
# [1.884712479352951, 20.764, 0.9516996145248413]
# [14200, 2.0838780403137207, 20.0]
# Folder already exists, beware of overriding old data!
# [1.8790358769893647, 20.902, 0.9527132511138916]
# [1.882061891555786, 20.77, 0.881550669670105]
# [1.8790358769893647, 20.902, 0.9527132511138916]
# [14300, 1.775150179862976, 27.0]
# Folder already exists, beware of overriding old data!
# [1.8929765875339508, 19.304, 0.9484567642211914]
# [1.8950304293632507, 19.26, 0.879411518573761]
# [1.8929765875339508, 19.304, 0.9484567642211914]
# [14400, 1.9294896125793457, 21.0]
# Folder already exists, beware of overriding old data!
# [1.895054169178009, 19.732, 0.9282172322273254]
# [1.8978293180465697, 19.89, 0.8709143400192261]
# [1.895054169178009, 19.732, 0.9282172322273254]
# [14500, 1.963992953300476, 18.0]
# Folder already exists, beware of overriding old data!
# [1.8787971024513244, 21.028, 0.9525333642959595]
# [1.8822780668735504, 20.81, 0.8708535432815552]
# [1.8787971024513244, 21.028, 0.9525333642959595]
# [14600, 1.869329810142517, 24.0]
# Folder already exists, beware of overriding old data!
# [1.88932475066185, 20.912, 0.9558076858520508]
# [1.8929770696163177, 21.03, 0.8772761821746826]
# [1.88932475066185, 20.912, 0.9558076858520508]
# [14700, 2.115043878555298, 14.0]
# Folder already exists, beware of overriding old data!
# [1.8832016558647156, 20.804, 0.9514033198356628]
# [1.8864568424224855, 20.82, 0.8820919394493103]
# [1.8832016558647156, 20.804, 0.9514033198356628]
# [14800, 1.8018308877944946, 30.0]
# Folder already exists, beware of overriding old data!
# [1.8959486780166626, 18.99, 0.9437136054039001]
# [1.8999121642112733, 18.93, 0.8798584342002869]
# [1.8959486780166626, 18.99, 0.9437136054039001]
# [14900, 1.9235037565231323, 21.0]
# Folder already exists, beware of overriding old data!
# [1.8796959447860717, 22.226, 0.9460721611976624]
# [1.8830857133865357, 22.15, 0.8723165988922119]
# [1.8796959447860717, 22.226, 0.9460721611976624]
# [15000, 2.025787591934204, 16.0]
# checking Hessian
# Folder already exists, beware of overriding old data!
# [1.8814990713596345, 20.808, 0.9419578909873962]
# [1.8847693288326264, 20.47, 0.8849889636039734]
# [1.8814990713596345, 20.808, 0.9419578909873962]
# [15100, 1.8968526124954224, 26.0]
# Folder already exists, beware of overriding old data!
# [1.8894992389678955, 20.14, 0.9596362113952637]
# [1.8929490375518798, 20.21, 0.884980320930481]
# [1.8894992389678955, 20.14, 0.9596362113952637]
# [15200, 2.0234715938568115, 19.0]
# Folder already exists, beware of overriding old data!
# [1.8814616117477416, 20.65, 0.9486454725265503]
# [1.8851933753490449, 20.65, 0.888772189617157]
# [1.8814616117477416, 20.65, 0.9486454725265503]
# [15300, 1.7443205118179321, 36.0]
# Folder already exists, beware of overriding old data!
# [1.8877178885936736, 20.838, 0.9424150586128235]
# [1.890361545085907, 20.78, 0.8940160274505615]
# [1.8877178885936736, 20.838, 0.9424150586128235]
# [15400, 1.9870390892028809, 25.0]
# Folder already exists, beware of overriding old data!
# [1.8805337429046631, 21.018, 0.9503054022789001]
# [1.8839057064056397, 21.11, 0.8745102882385254]
# [1.8805337429046631, 21.018, 0.9503054022789001]
# [15500, 2.0087409019470215, 16.0]
# Folder already exists, beware of overriding old data!
# [1.8732640523910522, 21.362, 0.9424546360969543]
# [1.8763819217681885, 21.27, 0.8850781917572021]
# [1.8732640523910522, 21.362, 0.9424546360969543]
# [15600, 2.0201539993286133, 23.0]
# Folder already exists, beware of overriding old data!
# [1.8869122185707092, 20.138, 0.9542780518531799]
# [1.8895088338851929, 20.45, 0.891212522983551]
# [1.8869122185707092, 20.138, 0.9542780518531799]
# [15700, 2.0422868728637695, 18.0]
# Folder already exists, beware of overriding old data!
# [1.8903763780593872, 20.542, 0.9521363973617554]
# [1.8939300382137298, 20.67, 0.8824478387832642]
# [1.8903763780593872, 20.542, 0.9521363973617554]
# [15800, 1.8655891418457031, 25.0]
# Folder already exists, beware of overriding old data!
# [1.8987641949653626, 20.754, 0.9496740102767944]
# [1.9012441658973693, 20.66, 0.8770516514778137]
# [1.8987641949653626, 20.754, 0.9496740102767944]
# [15900, 1.9191768169403076, 22.0]
# Folder already exists, beware of overriding old data!
# [1.87350763630867, 22.088, 0.9528011679649353]
# [1.876873584985733, 22.06, 0.8813578486442566]
# [1.87350763630867, 22.088, 0.9528011679649353]
# [16000, 1.9333882331848145, 19.0]
# Folder already exists, beware of overriding old data!
# [1.8788621516227721, 21.1, 0.9559905529022217]
# [1.8836334371566772, 21.0, 0.8885384798049927]
# [1.8788621516227721, 21.1, 0.9559905529022217]
# [16100, 1.9517006874084473, 21.0]
# Folder already exists, beware of overriding old data!
# [1.885387797832489, 20.334, 0.9547216296195984]
# [1.8899253165721894, 20.33, 0.8751591444015503]
# [1.885387797832489, 20.334, 0.9547216296195984]
# [16200, 2.068413019180298, 16.0]
# Folder already exists, beware of overriding old data!
# [1.880930813074112, 20.94, 0.945866048336029]
# [1.8847953617572784, 20.92, 0.8830805420875549]
# [1.880930813074112, 20.94, 0.945866048336029]
# [16300, 1.8849821090698242, 26.0]
# Folder already exists, beware of overriding old data!
# [1.8936417355537414, 20.5, 0.9446291327476501]
# [1.8959568524360657, 20.57, 0.8801790475845337]
# [1.8936417355537414, 20.5, 0.9446291327476501]
# [16400, 1.919980764389038, 23.0]
# Folder already exists, beware of overriding old data!
# [1.8736387894153594, 22.094, 0.9561351537704468]
# [1.8766345942020417, 22.18, 0.8705556392669678]
# [1.8736387894153594, 22.094, 0.9561351537704468]
# [16500, 2.007180690765381, 16.0]
# Folder already exists, beware of overriding old data!
# [1.8735034382343292, 20.604, 0.9587996602058411]
# [1.8772004354000091, 20.53, 0.900395929813385]
# [1.8735034382343292, 20.604, 0.9587996602058411]
# [16600, 1.887197732925415, 22.0]
# Folder already exists, beware of overriding old data!
# [1.8858170053958894, 20.56, 0.9547426104545593]
# [1.8892504930496217, 20.72, 0.8791704177856445]
# [1.8858170053958894, 20.56, 0.9547426104545593]
# [16700, 2.006648063659668, 20.0]
# Folder already exists, beware of overriding old data!
# [1.8961308007240296, 20.72, 0.945866048336029]
# [1.8992720174789428, 20.86, 0.8870969414710999]
# [1.8961308007240296, 20.72, 0.945866048336029]
# [16800, 1.8120455741882324, 32.0]
# Folder already exists, beware of overriding old data!
# [1.897423130273819, 20.62, 0.9538663625717163]
# [1.900493348836899, 20.72, 0.8992407917976379]
# [1.897423130273819, 20.62, 0.9538663625717163]
# [16900, 1.8857052326202393, 26.0]
# Folder already exists, beware of overriding old data!
# [1.8913990647792815, 21.182, 0.9558238387107849]
# [1.8953335642814637, 21.0, 0.8923490047454834]
# [1.8913990647792815, 21.182, 0.9558238387107849]
# [17000, 2.036437749862671, 15.0]
# Folder already exists, beware of overriding old data!
# [1.8834570128917694, 20.744, 0.9560228586196899]
# [1.887553426027298, 20.45, 0.8712084293365479]
# [1.8834570128917694, 20.744, 0.9560228586196899]
# [17100, 1.9350758790969849, 21.0]
# Folder already exists, beware of overriding old data!
# [1.8933613154888154, 20.922, 0.94399493932724]
# [1.8976914751529694, 20.84, 0.8692432641983032]
# [1.8933613154888154, 20.922, 0.94399493932724]
# [17200, 2.095038652420044, 19.0]
# Folder already exists, beware of overriding old data!
# [1.878381026506424, 21.062, 0.9552474021911621]
# [1.8824964249134064, 21.07, 0.8913052082061768]
# [1.878381026506424, 21.062, 0.9552474021911621]
# [17300, 1.7742806673049927, 35.0]
# Folder already exists, beware of overriding old data!
# [1.8896273083686828, 20.118, 0.9491035342216492]
# [1.8928998470306397, 20.32, 0.8855436444282532]
# [1.8896273083686828, 20.118, 0.9491035342216492]
# [17400, 1.8797703981399536, 16.0]
# Folder already exists, beware of overriding old data!
# [1.8734746208190918, 22.066, 0.9411307573318481]
# [1.8776411294937134, 21.84, 0.8628785014152527]
# [1.8734746208190918, 22.066, 0.9411307573318481]
# [17500, 1.994457721710205, 21.0]
# Folder already exists, beware of overriding old data!
# [1.8721458358764649, 20.906, 0.9399509429931641]
# [1.8762388908863068, 20.75, 0.8718323707580566]
# [1.8721458358764649, 20.906, 0.9399509429931641]
# [17600, 1.8936570882797241, 25.0]
# Folder already exists, beware of overriding old data!
# [1.8815983066558837, 20.518, 0.9552022218704224]
# [1.8854166746139527, 20.66, 0.8967348337173462]
# [1.8815983066558837, 20.518, 0.9552022218704224]
# [17700, 1.9615485668182373, 22.0]
# Folder already exists, beware of overriding old data!
# [1.8755913228988648, 20.922, 0.9519347548484802]
# [1.8795087873935699, 20.66, 0.8743771314620972]
# [1.8755913228988648, 20.922, 0.9519347548484802]
# [17800, 1.7607225179672241, 34.0]
# Folder already exists, beware of overriding old data!
# [1.8787872619628907, 20.718, 0.9359971880912781]
# [1.8826343846321105, 20.7, 0.8699430823326111]
# [1.8787872619628907, 20.718, 0.9359971880912781]
# [17900, 1.8993333578109741, 20.0]
# Folder already exists, beware of overriding old data!
# [1.8777284281253814, 21.072, 0.9556019902229309]
# [1.8820265114307404, 20.91, 0.8960525393486023]
# [1.8777284281253814, 21.072, 0.9556019902229309]
# [18000, 2.003502607345581, 13.0]
# Folder already exists, beware of overriding old data!
# [1.8730934946537017, 20.826, 0.960709810256958]
# [1.8769619107246398, 20.84, 0.8978489637374878]
# [1.8730934946537017, 20.826, 0.960709810256958]
# [18100, 1.9504791498184204, 24.0]
# Folder already exists, beware of overriding old data!
# [1.896383157968521, 20.726, 0.9462607502937317]
# [1.89911501288414, 21.03, 0.884333610534668]
# [1.896383157968521, 20.726, 0.9462607502937317]
# [18200, 2.0447838306427, 21.0]
# Folder already exists, beware of overriding old data!
# [1.8832834866046906, 20.996, 0.9436112642288208]
# [1.8861284482479095, 20.88, 0.8826932907104492]
# [1.8832834866046906, 20.996, 0.9436112642288208]
# [18300, 1.8283886909484863, 32.0]
# Folder already exists, beware of overriding old data!
# [1.880478376865387, 21.204, 0.9376747608184814]
# [1.8842359352111817, 21.07, 0.8673269748687744]
# [1.880478376865387, 21.204, 0.9376747608184814]
# [18400, 1.890209674835205, 22.0]
# Folder already exists, beware of overriding old data!
# [1.8774981696605682, 21.594, 0.9376201629638672]
# [1.882359380722046, 21.62, 0.8831954598426819]
# [1.8774981696605682, 21.594, 0.9376201629638672]
# [18500, 2.0384433269500732, 19.0]
# Folder already exists, beware of overriding old data!
# [1.8712278285026551, 20.898, 0.962242066860199]
# [1.8746373343467713, 20.97, 0.890647292137146]
# [1.8712278285026551, 20.898, 0.962242066860199]
# [18600, 1.9817438125610352, 24.0]
# Folder already exists, beware of overriding old data!
# [1.8897731940746307, 20.558, 0.963628888130188]
# [1.8937277507781982, 20.77, 0.8949478268623352]
# [1.8897731940746307, 20.558, 0.963628888130188]
# [18700, 2.0170111656188965, 18.0]
# Folder already exists, beware of overriding old data!
# [1.8829680845737458, 20.256, 0.9604297876358032]
# [1.886445564031601, 20.25, 0.8929100632667542]
# [1.8829680845737458, 20.256, 0.9604297876358032]
# [18800, 1.879970908164978, 26.0]
# Folder already exists, beware of overriding old data!
# [1.8963845820426941, 20.528, 0.9609824419021606]
# [1.9000115752220155, 20.48, 0.9031047821044922]
# [1.8963845820426941, 20.528, 0.9609824419021606]
# [18900, 1.8751728534698486, 20.0]
# Folder already exists, beware of overriding old data!
# [1.8806180760860443, 21.422, 0.9568719267845154]
# [1.884810701608658, 21.53, 0.8967249393463135]
# [1.8806180760860443, 21.422, 0.9568719267845154]
# [19000, 2.013181686401367, 20.0]
# Folder already exists, beware of overriding old data!
# [1.8734400277137757, 22.982, 0.9571328163146973]
# [1.8770671224594115, 23.13, 0.8998542428016663]
# [1.8734400277137757, 22.982, 0.9571328163146973]
# [19100, 2.003767967224121, 24.0]
# Folder already exists, beware of overriding old data!
# [1.8781681616306305, 21.866, 0.959236204624176]
# [1.881850643157959, 21.99, 0.8983011841773987]
# [1.8781681616306305, 21.866, 0.959236204624176]
# [19200, 2.0604684352874756, 22.0]
# Folder already exists, beware of overriding old data!
# [1.892933798313141, 21.128, 0.9651021361351013]
# [1.8964878416061401, 21.14, 0.8960874676704407]
# [1.892933798313141, 21.128, 0.9651021361351013]
# [19300, 1.8227591514587402, 33.0]
# Folder already exists, beware of overriding old data!
# [1.8784246604442596, 20.756, 0.951728880405426]
# [1.8823455321788787, 21.06, 0.8977075815200806]
# [1.8784246604442596, 20.756, 0.951728880405426]
# [19400, 1.8925881385803223, 22.0]
# Folder already exists, beware of overriding old data!
# [1.8793922550678253, 21.362, 0.9601317644119263]
# [1.8825940537452697, 21.56, 0.8906731009483337]
# [1.8793922550678253, 21.362, 0.9601317644119263]
# [19500, 2.0231096744537354, 22.0]
# Folder already exists, beware of overriding old data!
# [1.8795719304084777, 21.486, 0.9633103013038635]
# [1.8840829622745514, 21.71, 0.8892474174499512]
# [1.8795719304084777, 21.486, 0.9633103013038635]
# [19600, 1.9794164896011353, 26.0]
# Folder already exists, beware of overriding old data!
# [1.886371467590332, 21.01, 0.9620183706283569]
# [1.891331466436386, 21.03, 0.9011147618293762]
# [1.886371467590332, 21.01, 0.9620183706283569]
# [19700, 1.9864637851715088, 20.0]
# Folder already exists, beware of overriding old data!
# [1.8806978585720062, 21.508, 0.9586189389228821]
# [1.884633252620697, 21.47, 0.8921828866004944]
# [1.8806978585720062, 21.508, 0.9586189389228821]
# [19800, 1.8120172023773193, 27.0]
# Folder already exists, beware of overriding old data!
# [1.8800739300251008, 20.756, 0.9510248899459839]
# [1.8842204642295837, 20.75, 0.8856486678123474]
# [1.8800739300251008, 20.756, 0.9510248899459839]
# [19900, 1.92857027053833, 21.0]
# Folder already exists, beware of overriding old data!
# [1.8791033420562744, 21.942, 0.9494744539260864]
# [1.8829494953155517, 22.05, 0.8982237577438354]
# [1.8791033420562744, 21.942, 0.9494744539260864]
# [20000, 2.0433318614959717, 16.0]
# checking Hessian
# Folder already exists, beware of overriding old data!
# eval time 20001
# [1.8758725700378418, 21.81, 0.9524847269058228]
# [1.880391012430191, 21.86, 0.889333963394165]
# [1.8758725700378418, 21.81, 0.9524847269058228]
# Folder already exists, beware of overriding old data!

# %%
# !zip -r alexnet4.zip /content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet /content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet
# Out:
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/ (stored 0%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/evaluation_history_TEST.hist (deflated 48%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/eigenvalues_step20000.pyT (deflated 57%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/weight_history.hist (deflated 85%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/trall_outputs.pyT (deflated 16%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/noise_norm_history_TRAINALL.hist (deflated 20%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/te_outputs.pyT (deflated 16%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/eigenvalues_step0.pyT (deflated 58%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/evaluation_history_TRAINALL.hist (deflated 43%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/noise_norm_history_TEST.hist (deflated 38%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/eigenvalues_step15000.pyT (deflated 57%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/eigenvalues.pyT (deflated 57%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/tr_outputs.pyT (deflated 16%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/eigenvalues_step5000.pyT (deflated 57%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/evaluation_history_TRAIN.hist (deflated 43%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/net.pyT (deflated 42%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/training_history.hist (deflated 66%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/noise_norm_history_TRAIN.hist (deflated 20%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/eigenvalues_step10000.pyT (deflated 58%)
#   adding: content/results_FC_scales/2_0004_00_cifar10_NLL_alexnet/args.info (deflated 43%)

# %% [markdown]
# ## alpha is much smaller than 2

# %%
import torch
import numpy as np


evaluation_history_TEST = torch.load(save_dir + '/evaluation_history_TEST.hist')
evaluation_history_TEST = np.array(evaluation_history_TEST)[:-1] # remove the last result,
                                                                 # which is evaluated at the end of training
evaluation_history_TRAIN = torch.load(save_dir + '/evaluation_history_TRAIN.hist')
# evaluation_history_TRAIN.hist saves all evaluation done on the **whole** training set
evaluation_history_TRAIN = np.array(evaluation_history_TRAIN)[:-1]

# %%
# we compute the average of the tail-index measurements for the last 10K iterations
averaged_alpha_TEST = evaluation_history_TEST[-10000//eval_freq:,-1].mean() 
averaged_alpha_TRAIN = evaluation_history_TRAIN[-10000//eval_freq:,-1].mean() 

print('averaged alpha (test): %f'%averaged_alpha_TEST)
print('averaged alpha (train): %f'%averaged_alpha_TRAIN)
# Out:
# averaged alpha (test): 0.875877
# averaged alpha (train): 0.946165

# %% [markdown]
# ## Show it's heavily tailed

# %%
normgrad = np.reshape(noise_norm_history_TRAIN, (-1))

fig,ax=plt.subplots(1,2,figsize=(10,5))
ax[0].hist(normgrad, bins=100)
ax[0].set_yscale('log')
ax[0].set_title('Real')
gaussian = np.random.normal(loc=0.8, scale=0.5, size=1000000)
ax[1].hist(gaussian, bins=100)
ax[1].set_yscale('log')
ax[1].set_xlim([0,4])
ax[1].set_title('Gaussian')
plt.show()

# %% [markdown]
# ## At the end of training, it ends up in a flat and wide region with most eigenvalues close to 0
#
# - But there are several large Hessian outliers.
# - loss are plotted to prove the model has been "resting" here for quite a while

# %%
# check the Hessian
density_eigen, density_weight = torch.load(save_dir + '/eigenvalues_step20000.pyT')
from density_plot import get_esd_plot # ESD plot
get_esd_plot(density_eigen, density_weight)
plt.axvline(0,c='k')

# %%
# show loss plot to prove the model has been "resting" here for quite a while
sub, up = close_check_lb//close_check_freq, close_check_lb//close_check_freq+(close_check_hb-close_check_lb)//close_check_freq
xtrain = list(range(0,iter+eval_freq,eval_freq))

loss_early_TRAIN = evaluation_history_TRAIN[:,1].copy()
loss_early_TRAIN = np.concatenate((loss_early_TRAIN[:sub],loss_early_TRAIN[sub:up:sample_step],loss_early_TRAIN[up:]))
plt.plot(xtrain,loss_early_TRAIN)

# %% [markdown]
# ## wanna show the escape from the local minimum
#
# - Not yet successful

# %%
import matplotlib.pyplot as plt

# we record the dynamics of the tail-index measurements for the first 10k iterations
# alpha_early_TEST = evaluation_history_TEST[:,-1].copy()
alpha_early_TRAIN = evaluation_history_TRAIN[:,-1].copy()
# and loss and accuracy
# accuracy_early_TEST = evaluation_history_TEST[:,-2].copy()
# loss_early_TEST = evaluation_history_TEST[:,1].copy()
# loss_early_TEST[117] = (loss_early_TEST[116]+loss_early_TEST[118])/2 # wird point..
# accuracy_early_TEST[117] = (accuracy_early_TEST[116]+accuracy_early_TEST[118])/2 # wird point..
accuracy_early_TRAIN = evaluation_history_TRAIN[:,-2].copy()
loss_early_TRAIN = evaluation_history_TRAIN[:,1].copy()

### there is a part during training
### where I recorded statistics every 10 iters (instead of 100)
### we can either smooth
# def smooth(y, box_pts):
#     box = np.ones(box_pts)/box_pts
#     y_smooth = np.convolve(y, box, mode='valid')
#     return y_smooth

# N = 9
sub, up = close_check_lb//close_check_freq, close_check_lb//close_check_freq+(close_check_hb-close_check_lb)//close_check_freq
# alpha_early_TRAIN[sub+N//2:up-N//2] = smooth(alpha_early_TRAIN[sub:up],N)
# alpha_early_TEST[sub+N//2:up-N//2] = smooth(alpha_early_TEST[sub:up],N)
# accuracy_early_TRAIN[sub+N//2:up-N//2] = smooth(accuracy_early_TRAIN[sub:up],N)
# accuracy_early_TEST[sub+N//2:up-N//2] = smooth(accuracy_early_TEST[sub:up],N)
# loss_early_TRAIN[sub+N//2:up-N//2] = smooth(loss_early_TRAIN[sub:up],N)
# loss_early_TEST[sub+N//2:up-N//2] = smooth(loss_early_TEST[sub:up],N)

### or sample
sample_step = 100//10
alpha_early_TRAIN = np.concatenate((alpha_early_TRAIN[:sub],alpha_early_TRAIN[sub:up:sample_step],alpha_early_TRAIN[up:]))
accuracy_early_TRAIN = np.concatenate((accuracy_early_TRAIN[:sub],accuracy_early_TRAIN[sub:up:sample_step],accuracy_early_TRAIN[up:]))
loss_early_TRAIN = np.concatenate((loss_early_TRAIN[:sub],loss_early_TRAIN[sub:up:sample_step],loss_early_TRAIN[up:]))


fig, ax = plt.subplots(3,1,figsize=(16,8),sharex=True)
# !!!xaxis is not correct yet!!!
# xtest = list(range(0,900,100))+list(range(900,2000,10),)+list(range(2000,11100,100))
xtrain = list(range(0,20100,100))
# xtrain = list(range(0,900,100))+list(range(900,2000,10),)+list(range(2000,11100,100))
# xtrain = list(range(0,(len(alpha_early_TRAIN))*eval_freq, eval_freq))
ax[0].plot(xtrain,alpha_early_TRAIN, label='train')
# ax[0].plot(xtest,alpha_early_TEST, label='test')
ax[0].legend()
ax[0].set_title('Estimated alpha')
ax[1].plot(xtrain,accuracy_early_TRAIN)
# ax[1].plot(xtest,accuracy_early_TEST)
ax[1].set_title('Accuracy %')
ax[2].plot(xtrain,loss_early_TRAIN)
# ax[2].plot(xtest,loss_early_TEST)
ax[2].set_title('loss')
ax[0].set_xscale('log')
