# %%
# %matplotlib inline
import os
import subprocess
import itertools
import time
import torch

import numpy as np
import matplotlib.pyplot as plt

# analysis of Hessian
# !git clone https://github.com/amirgholami/PyHessian.git
import sys
sys.path.append('/content/PyHessian/')



# folder to save
base_path = 'results_FC_scales'

if not os.path.exists(base_path):
    os.makedirs(base_path)

# server setup
# launcher = "srun --nodes=1 --gres=gpu:1 --time=40:00:00 --mem=60G" # THIS IS AN EXAMPLE!!!

# experimental setup
# width = [4, 8, 16, 32, 64, 128, 256, 512, 1024]
# depth = [2, 3, 4, 5, 6, 7, 8, 9, 10]
# seeds = list(range(3))
# dataset = ['mnist', 'cifar10']
# loss = ['NLL','linear_hinge']
# dataset = ['mnist']
# model = ['fc']
w = 16
dep = 2
s = 0
l = 'NLL'
d = 'cifar10'
m = 'alexnet'

iter = 20000
eval_freq = 100 # don't vary it; keep it the same as in the code
close_check_lb = 0
close_check_hb = 0
close_check_freq = 10 # set to eval_freq to remove the finer sampling 
                      # of certain iteration regions [close_check_lb, close_check_hb]
eval_Hessian_freq = 5000
# grid = itertools.product(width, depth, seeds, dataset, loss, model)

processes = []
# for w, dep, s, d, l, m in grid:

save_dir = base_path + '/{}_{:04d}_{:02d}_{}_{}_{}'.format(dep, w, s, d, l, m)
if os.path.exists(save_dir):
    # folder created only at the end when all is done!
    print('folder already exists, quitting')
    # continue

# cmd = launcher + ' '
cmd = 'python main.py '
cmd += '--save_dir {} '.format(save_dir)
if m == 'fc':
  cmd += '--width {} '.format(w)
elif m == 'alexnet':
  cmd += '--scale {} '.format(w)
cmd += '--depth {} '.format(dep)
cmd += '--seed {} '.format(s)
cmd += '--dataset {} '.format(d)
cmd += '--model {} '.format(m)
cmd += '--lr {} '.format('0.1')
cmd += '--lr_schedule '
cmd += '--iterations {} '.format(iter)
cmd += '--eval_freq {} '.format(eval_freq)
cmd += '--close_check_lb {} '.format(close_check_lb)
cmd += '--close_check_hb {} '.format(close_check_hb)
cmd += '--close_check_freq {} '.format(close_check_freq)
cmd += '--eval_Hessian_freq {} '.format(eval_Hessian_freq)
# cmd += '--print_freq {} '.format(1), # dbg
# cmd += '--verbose '

# print(cmd)

f = open(save_dir + '.log', 'w')

print(cmd)
# subprocess.Popen(cmd.split(), stdout=f, stderr=f)#.wait()
# Out:
# fatal: destination path 'PyHessian' already exists and is not an empty directory.
# folder already exists, quitting
# python main.py --save_dir results_FC_scales/2_0016_00_cifar10_NLL_alexnet --scale 16 --depth 2 --seed 0 --dataset cifar10 --model alexnet --lr 0.1 --lr_schedule --iterations 20000 --eval_freq 100 --close_check_lb 0 --close_check_hb 0 --close_check_freq 10 --eval_Hessian_freq 5000

# %%
# !python main.py --save_dir results_FC_scales/2_0016_00_cifar10_NLL_alexnet --scale 16 --depth 2 --seed 0 --dataset cifar10 --model alexnet --lr 0.1 --lr_schedule --iterations 20000 --eval_freq 100 --close_check_lb 0 --close_check_hb 0 --close_check_freq 10 --eval_Hessian_freq 5000
# Out:
# Namespace(batch_size_eval=100, batch_size_train=100, close_check_freq=10, close_check_hb=0, close_check_lb=0, criterion='NLL', dataset='cifar10', depth=2, device=device(type='cpu'), double=False, eval_Hessian_freq=5000, eval_freq=100, iterations=20000, lr=0.1, lr_schedule=True, model='alexnet', mom=0, no_cuda=False, path='./data', print_freq=100, save_dir='results_FC_scales/2_0016_00_cifar10_NLL_alexnet', scale=16, seed=0, use_cuda=False, verbose=False, wd=0, width=100)
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 170499072it [00:03, 42743532.19it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# torch.Size([1, 16, 1, 1])
# 16
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(16, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=16, out_features=80, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=80, out_features=80, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=80, out_features=10, bias=True)
#   )
# )
# [2.306014692783356, 10.0, 0.48726409673690796]
# [2.306006600856781, 10.0, 0.5308911800384521]
# [0, 2.306774139404297, 11.0]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:154: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# checking Hessian
# Folder already exists, beware of overriding old data!
# [2.302922308444977, 10.0, 0.4899277687072754]
# [2.3029143776893615, 10.0, 0.5331029295921326]
# [100, 2.2998955249786377, 11.0]
# Folder already exists, beware of overriding old data!
# [2.3026008868217467, 10.0, 0.4899037480354309]
# [2.302593259811401, 10.0, 0.5375698804855347]
# [200, 2.3017847537994385, 12.0]
# Folder already exists, beware of overriding old data!
# [2.302788641452789, 10.6, 0.49113979935646057]
# [2.3027816133499144, 10.566, 0.5353484153747559]
# [300, 2.2955548763275146, 17.0]
# Folder already exists, beware of overriding old data!
# [2.3023915243148805, 12.16, 0.4980281591415405]
# [2.3023843393325807, 12.714, 0.5415465831756592]
# [400, 2.3094096183776855, 3.0]
# Folder already exists, beware of overriding old data!
# [2.3023511242866515, 9.99, 0.4975159168243408]
# [2.3023363699913024, 10.004, 0.5421126484870911]
# [500, 2.303417205810547, 9.0]
# Folder already exists, beware of overriding old data!
# [2.3021174097061157, 11.1, 0.4994681179523468]
# [2.3021061582565308, 11.01, 0.5417256951332092]
# [600, 2.3018178939819336, 8.0]
# Folder already exists, beware of overriding old data!
# [2.300304498672485, 10.0, 0.5105016827583313]
# [2.300303900718689, 10.0, 0.5514369010925293]
# [700, 2.297428846359253, 15.0]
# Folder already exists, beware of overriding old data!
# [2.2877531480789184, 10.09, 0.5432242751121521]
# [2.287850371837616, 10.118, 0.5847659707069397]
# [800, 2.28509259223938, 13.0]
# Folder already exists, beware of overriding old data!
# [2.2565187668800353, 12.76, 0.5791276693344116]
# [2.255945912837982, 12.774, 0.6204094886779785]
# [900, 2.23921799659729, 12.0]
# Folder already exists, beware of overriding old data!
# [2.0523165392875673, 19.96, 0.5804733037948608]
# [2.0547671535015106, 19.87, 0.6176439523696899]
# [1000, 2.138261318206787, 11.0]
# Folder already exists, beware of overriding old data!
# [2.003075478076935, 18.63, 0.5857915282249451]
# [2.0029178891181947, 18.418, 0.6288790106773376]
# [1100, 2.0120885372161865, 20.0]
# Folder already exists, beware of overriding old data!
# [2.0248069632053376, 18.48, 0.5876070261001587]
# [2.0243615260124206, 17.992, 0.6334593892097473]
# [1200, 2.0107507705688477, 15.0]
# Folder already exists, beware of overriding old data!
# [1.9495950722694397, 19.1, 0.5805640816688538]
# [1.9482293519973755, 18.898, 0.6196572184562683]
# [1300, 1.8979368209838867, 24.0]
# Folder already exists, beware of overriding old data!
# [1.9932948231697083, 19.01, 0.5789532661437988]
# [1.9910151267051697, 18.958, 0.6215935945510864]
# [1400, 1.9280869960784912, 19.0]
# Folder already exists, beware of overriding old data!
# [1.9717964005470277, 19.96, 0.5729793310165405]
# [1.9699851326942444, 19.91, 0.6090744733810425]
# [1500, 1.9790375232696533, 16.0]
# Folder already exists, beware of overriding old data!
# [2.005766135454178, 18.05, 0.5760225057601929]
# [2.0014667024612427, 17.85, 0.6147589087486267]
# [1600, 1.905258297920227, 20.0]
# Folder already exists, beware of overriding old data!
# [1.9795733320713043, 18.52, 0.580299973487854]
# [1.9755257351398468, 18.186, 0.622291624546051]
# [1700, 1.9827253818511963, 25.0]
# Folder already exists, beware of overriding old data!
# [1.945339684486389, 20.94, 0.5870916843414307]
# [1.943745887517929, 20.842, 0.627617359161377]
# [1800, 1.819830298423767, 26.0]
# Folder already exists, beware of overriding old data!
# [1.9691028094291687, 18.66, 0.5828053951263428]
# [1.9670164012908935, 18.75, 0.6179817318916321]
# [1900, 1.8427239656448364, 23.0]
# Folder already exists, beware of overriding old data!
# [1.962892026901245, 19.21, 0.5897477269172668]
# [1.9605346772670746, 19.196, 0.63029545545578]
# [2000, 1.9201947450637817, 13.0]
# Folder already exists, beware of overriding old data!
# [1.9306274807453156, 20.36, 0.5703397989273071]
# [1.928481817960739, 20.168, 0.6136097311973572]
# [2100, 1.8653010129928589, 27.0]
# Folder already exists, beware of overriding old data!
# [1.949904887676239, 20.47, 0.5805127024650574]
# [1.9481831860542298, 20.098, 0.6205316185951233]
# [2200, 1.9688664674758911, 19.0]
# Folder already exists, beware of overriding old data!
# [1.9171088302135468, 21.33, 0.586573600769043]
# [1.9154887189865113, 21.194, 0.6282262802124023]
# [2300, 1.7545086145401, 31.0]
# Folder already exists, beware of overriding old data!
# [1.9828676438331605, 19.24, 0.5968376398086548]
# [1.9818834466934203, 18.856, 0.6399277448654175]
# [2400, 1.8233729600906372, 28.0]
# Folder already exists, beware of overriding old data!
# [1.9643586266040802, 20.07, 0.606482207775116]
# [1.9630198719501495, 19.688, 0.654825747013092]
# [2500, 1.8770354986190796, 25.0]
# Folder already exists, beware of overriding old data!
# [1.910267435312271, 24.19, 0.6379716992378235]
# [1.9102162914276124, 23.986, 0.6756099462509155]
# [2600, 1.8232837915420532, 30.0]
# Folder already exists, beware of overriding old data!
# [1.8816387581825256, 25.16, 0.6557161808013916]
# [1.8818988144397735, 24.96, 0.7022547125816345]
# [2700, 1.9062860012054443, 25.0]
# Folder already exists, beware of overriding old data!
# [1.7659831249713898, 27.83, 0.6778395771980286]
# [1.7628550641536713, 27.646, 0.7197221517562866]
# [2800, 1.8143757581710815, 35.0]
# Folder already exists, beware of overriding old data!
# [2.011456207036972, 21.93, 0.7046690583229065]
# [2.012212378501892, 21.822, 0.7436395883560181]
# [2900, 1.888485312461853, 23.0]
# Folder already exists, beware of overriding old data!
# [1.8329999840259552, 27.39, 0.7181569337844849]
# [1.836572951555252, 27.36, 0.7662255764007568]
# [3000, 1.8991600275039673, 28.0]
# Folder already exists, beware of overriding old data!
# [1.8010177826881408, 27.84, 0.6996336579322815]
# [1.8008696677684783, 27.676, 0.751663088798523]
# [3100, 1.700823187828064, 34.0]
# Folder already exists, beware of overriding old data!
# [1.8109284698963166, 27.73, 0.7422403693199158]
# [1.8119098596572876, 27.756, 0.7864808440208435]
# [3200, 1.8098567724227905, 26.0]
# Folder already exists, beware of overriding old data!
# [1.7324732971191406, 31.42, 0.7497482895851135]
# [1.731239926815033, 31.516, 0.7876323461532593]
# [3300, 1.6187584400177002, 35.0]
# Folder already exists, beware of overriding old data!
# [1.938811787366867, 23.1, 0.7285583019256592]
# [1.9413861858844756, 23.186, 0.773533046245575]
# [3400, 1.8822312355041504, 19.0]
# Folder already exists, beware of overriding old data!
# [1.8275700104236603, 28.43, 0.7465456128120422]
# [1.830105622768402, 28.008, 0.7913708686828613]
# [3500, 1.776829719543457, 33.0]
# Folder already exists, beware of overriding old data!
# [1.8157649838924408, 26.7, 0.7418829202651978]
# [1.8176881911754608, 26.646, 0.790418803691864]
# [3600, 1.6963462829589844, 34.0]
# Folder already exists, beware of overriding old data!
# [1.8651844263076782, 26.01, 0.720341145992279]
# [1.8642032489776612, 26.326, 0.7754139304161072]
# [3700, 1.9011425971984863, 24.0]
# Folder already exists, beware of overriding old data!
# [1.8540597116947175, 27.87, 0.7141819000244141]
# [1.851862616300583, 28.16, 0.760280430316925]
# [3800, 1.6699928045272827, 37.0]
# Folder already exists, beware of overriding old data!
# [1.8451839566230774, 27.09, 0.7476284503936768]
# [1.8511282653808594, 26.544, 0.7980947494506836]
# [3900, 1.5622767210006714, 38.0]
# Folder already exists, beware of overriding old data!
# [1.7933414661884308, 30.15, 0.735319197177887]
# [1.7895322995185852, 30.17, 0.7775568962097168]
# [4000, 1.6834145784378052, 31.0]
# Folder already exists, beware of overriding old data!
# [1.8596316909790038, 26.74, 0.7321040630340576]
# [1.8621395225524902, 26.376, 0.7878232002258301]
# [4100, 1.6484107971191406, 37.0]
# Folder already exists, beware of overriding old data!
# [1.7609403312206269, 30.64, 0.740027904510498]
# [1.752041589975357, 31.21, 0.7889647483825684]
# [4200, 1.639683723449707, 39.0]
# Folder already exists, beware of overriding old data!
# [1.6286571168899535, 37.24, 0.7399482727050781]
# [1.6180155355930328, 38.288, 0.7888903021812439]
# [4300, 1.4354737997055054, 53.0]
# Folder already exists, beware of overriding old data!
# [1.773034269809723, 29.51, 0.7598749995231628]
# [1.7721502323150635, 29.524, 0.8132182359695435]
# [4400, 1.5344853401184082, 34.0]
# Folder already exists, beware of overriding old data!
# [1.7795322120189667, 31.9, 0.7624315619468689]
# [1.7699047968387605, 32.092, 0.8134313821792603]
# [4500, 1.6952787637710571, 31.0]
# Folder already exists, beware of overriding old data!
# [1.7826539778709412, 30.91, 0.7398634552955627]
# [1.7769774284362794, 31.126, 0.7943171858787537]
# [4600, 1.4888029098510742, 46.0]
# Folder already exists, beware of overriding old data!
# [1.7037735283374786, 32.86, 0.7599465847015381]
# [1.6894886794090271, 33.246, 0.8113858699798584]
# [4700, 1.6499131917953491, 39.0]
# Folder already exists, beware of overriding old data!
# [1.635436829328537, 36.26, 0.7492397427558899]
# [1.626377610206604, 37.03, 0.7992197275161743]
# [4800, 1.4116318225860596, 48.0]
# Folder already exists, beware of overriding old data!
# [1.930719904899597, 26.57, 0.7775147557258606]
# [1.9360604572296143, 25.932, 0.8402541875839233]
# [4900, 1.6628040075302124, 34.0]
# Folder already exists, beware of overriding old data!
# [1.7087496149539947, 33.34, 0.7752025723457336]
# [1.6937953815460205, 33.984, 0.8284469842910767]
# [5000, 1.5457687377929688, 36.0]
# checking Hessian
# Folder already exists, beware of overriding old data!
# [1.8559535598754884, 30.26, 0.7717820405960083]
# [1.8540842242240905, 30.098, 0.82423335313797]
# [5100, 1.4717425107955933, 46.0]
# Folder already exists, beware of overriding old data!
# [1.6754862773418426, 34.46, 0.7778217196464539]
# [1.6584866540431977, 35.15, 0.8329370617866516]
# [5200, 1.5257580280303955, 41.0]
# Folder already exists, beware of overriding old data!
# [1.60197882771492, 39.47, 0.7714396715164185]
# [1.5813425023555756, 40.506, 0.8232574462890625]
# [5300, 1.3985449075698853, 49.0]
# Folder already exists, beware of overriding old data!
# [1.7621154034137725, 32.03, 0.8101258873939514]
# [1.7498962914943694, 32.396, 0.8569604754447937]
# [5400, 1.467137098312378, 38.0]
# Folder already exists, beware of overriding old data!
# [1.7748281610012056, 33.3, 0.8044167757034302]
# [1.7559846475124359, 33.662, 0.8500720858573914]
# [5500, 1.5493844747543335, 36.0]
# Folder already exists, beware of overriding old data!
# [1.7090889763832093, 32.27, 0.8356651067733765]
# [1.6889080293178558, 33.238, 0.8889705538749695]
# [5600, 1.5452182292938232, 42.0]
# Folder already exists, beware of overriding old data!
# [1.5931899917125703, 38.72, 0.8364668488502502]
# [1.571587828874588, 39.72, 0.8842341303825378]
# [5700, 1.5349098443984985, 40.0]
# Folder already exists, beware of overriding old data!
# [1.5338168525695801, 42.63, 0.8544282913208008]
# [1.5128552794456482, 44.316, 0.9013678431510925]
# [5800, 1.4753754138946533, 48.0]
# Folder already exists, beware of overriding old data!
# [1.7073218095302582, 36.18, 0.8645918965339661]
# [1.6863512179851532, 36.834, 0.9134295582771301]
# [5900, 1.4608372449874878, 43.0]
# Folder already exists, beware of overriding old data!
# [1.6391172099113465, 38.13, 0.8368914127349854]
# [1.6149556958675384, 39.21, 0.8851510882377625]
# [6000, 1.6232246160507202, 35.0]
# Folder already exists, beware of overriding old data!
# [1.622635806798935, 36.31, 0.819361686706543]
# [1.596382329940796, 37.382, 0.8611136078834534]
# [6100, 1.455820918083191, 44.0]
# Folder already exists, beware of overriding old data!
# [1.6670069265365601, 36.83, 0.8352026343345642]
# [1.6427770726680755, 37.252, 0.8887242078781128]
# [6200, 1.5588854551315308, 42.0]
# Folder already exists, beware of overriding old data!
# [1.547220002412796, 41.58, 0.839364230632782]
# [1.5204951989650726, 43.104, 0.8976389169692993]
# [6300, 1.388146162033081, 46.0]
# Folder already exists, beware of overriding old data!
# [1.6362625503540038, 38.38, 0.8706585764884949]
# [1.6108770670890808, 39.018, 0.9089083671569824]
# [6400, 1.3482425212860107, 47.0]
# Folder already exists, beware of overriding old data!
# [1.6533727860450744, 38.45, 0.8659766912460327]
# [1.6280930886268616, 39.074, 0.9073918461799622]
# [6500, 1.6215357780456543, 32.0]
# Folder already exists, beware of overriding old data!
# [1.643642122745514, 35.34, 0.8524779677391052]
# [1.6174764575958251, 36.26, 0.9078598618507385]
# [6600, 1.396306037902832, 48.0]
# Folder already exists, beware of overriding old data!
# [1.5705007874965669, 39.21, 0.8574077486991882]
# [1.5387175676822662, 40.194, 0.9174705147743225]
# [6700, 1.4768809080123901, 43.0]
# Folder already exists, beware of overriding old data!
# [1.5222459840774536, 42.72, 0.8428146243095398]
# [1.4823666625022889, 44.246, 0.8987305164337158]
# [6800, 1.2920399904251099, 48.0]
# Folder already exists, beware of overriding old data!
# [1.5140678882598877, 41.21, 0.8664385676383972]
# [1.4766262898445128, 42.784, 0.9129851460456848]
# [6900, 1.3344982862472534, 45.0]
# Folder already exists, beware of overriding old data!
# [1.5406939566135407, 42.76, 0.8651202321052551]
# [1.5050642786026, 44.31, 0.9108667373657227]
# [7000, 1.5477006435394287, 45.0]
# Folder already exists, beware of overriding old data!
# [1.5388646161556243, 40.41, 0.8531618118286133]
# [1.5016288242340088, 41.436, 0.9065778255462646]
# [7100, 1.3583135604858398, 55.0]
# Folder already exists, beware of overriding old data!
# [1.6292340648174286, 37.97, 0.865461528301239]
# [1.5889461023807525, 38.61, 0.9180489778518677]
# [7200, 1.4385812282562256, 46.0]
# Folder already exists, beware of overriding old data!
# [1.4892872154712677, 44.34, 0.8676629662513733]
# [1.4471233978271485, 45.962, 0.9231084585189819]
# [7300, 1.2714253664016724, 55.0]
# Folder already exists, beware of overriding old data!
# [1.5520708060264587, 40.2, 0.8839656710624695]
# [1.5084664499759675, 41.644, 0.9237950444221497]
# [7400, 1.2559363842010498, 53.0]
# Folder already exists, beware of overriding old data!
# [1.531718018054962, 42.13, 0.8847103714942932]
# [1.4868714451789855, 43.57, 0.9327588081359863]
# [7500, 1.4964375495910645, 45.0]
# Folder already exists, beware of overriding old data!
# [1.5699656867980958, 38.97, 0.8672511577606201]
# [1.5292666444778442, 40.236, 0.9197676777839661]
# [7600, 1.311707615852356, 53.0]
# Folder already exists, beware of overriding old data!
# [1.5740903449058532, 39.41, 0.8612926602363586]
# [1.5262623987197876, 40.566, 0.921725869178772]
# [7700, 1.4472203254699707, 49.0]
# Folder already exists, beware of overriding old data!
# [1.4694395565986633, 44.78, 0.8564542531967163]
# [1.4188696587085723, 46.81, 0.9173169732093811]
# [7800, 1.2719876766204834, 54.0]
# Folder already exists, beware of overriding old data!
# [1.515536780357361, 41.72, 0.891371488571167]
# [1.4679434270858764, 43.512, 0.9319539666175842]
# [7900, 1.1891183853149414, 54.0]
# Folder already exists, beware of overriding old data!
# [1.5568987464904784, 41.55, 0.8722811341285706]
# [1.5087027292251587, 43.332, 0.9178794026374817]
# [8000, 1.6171337366104126, 43.0]
# Folder already exists, beware of overriding old data!
# [1.5537297606468201, 38.81, 0.892841100692749]
# [1.503579790353775, 40.5, 0.9451498985290527]
# [8100, 1.3008036613464355, 55.0]
# Folder already exists, beware of overriding old data!
# [1.581431623697281, 38.77, 0.8895448446273804]
# [1.5327717740535736, 40.124, 0.9387989640235901]
# [8200, 1.4139297008514404, 44.0]
# Folder already exists, beware of overriding old data!
# [1.438135312795639, 46.24, 0.8872194290161133]
# [1.387865966796875, 48.492, 0.9332384467124939]
# [8300, 1.3207670450210571, 53.0]
# Folder already exists, beware of overriding old data!
# [1.5148528838157653, 40.47, 0.8711422681808472]
# [1.4684863612651824, 42.304, 0.9305675625801086]
# [8400, 1.2736401557922363, 52.0]
# Folder already exists, beware of overriding old data!
# [1.5391399812698365, 40.92, 0.8828917741775513]
# [1.4904850926399231, 42.302, 0.9289965033531189]
# [8500, 1.5178511142730713, 47.0]
# Folder already exists, beware of overriding old data!
# [1.560277934074402, 40.21, 0.880800187587738]
# [1.5071746594905853, 41.432, 0.9421325922012329]
# [8600, 1.3167109489440918, 50.0]
# Folder already exists, beware of overriding old data!
# [1.5970682942867278, 36.35, 0.8859288692474365]
# [1.5457392177581788, 37.468, 0.9335043430328369]
# [8700, 1.4530014991760254, 48.0]
# Folder already exists, beware of overriding old data!
# [1.4754627823829651, 43.47, 0.8904958367347717]
# [1.417757775783539, 45.188, 0.9378020167350769]
# [8800, 1.2944533824920654, 51.0]
# Folder already exists, beware of overriding old data!
# [1.5315150952339172, 41.07, 0.88909512758255]
# [1.4793989343643188, 42.364, 0.936876654624939]
# [8900, 1.2683731317520142, 53.0]
# Folder already exists, beware of overriding old data!
# [1.5839872074127197, 40.26, 0.8804192543029785]
# [1.5308936166763305, 41.128, 0.930804967880249]
# [9000, 1.4585297107696533, 51.0]
# Folder already exists, beware of overriding old data!
# [1.5499803686141969, 39.66, 0.8910273313522339]
# [1.498881814479828, 41.316, 0.9463356733322144]
# [9100, 1.3342976570129395, 48.0]
# Folder already exists, beware of overriding old data!
# [1.6510963881015777, 37.23, 0.8916299343109131]
# [1.597974098443985, 38.29, 0.9457511305809021]
# [9200, 1.4938732385635376, 49.0]
# Folder already exists, beware of overriding old data!
# [1.464707555770874, 42.98, 0.8969587087631226]
# [1.4050103366374969, 44.918, 0.9437389969825745]
# [9300, 1.2163760662078857, 53.0]
# Folder already exists, beware of overriding old data!
# [1.5321036994457244, 41.8, 0.900966465473175]
# [1.480502427816391, 43.478, 0.9522879123687744]
# [9400, 1.2369319200515747, 49.0]
# Folder already exists, beware of overriding old data!
# [1.504203931093216, 41.06, 0.8784030079841614]
# [1.452831847667694, 42.846, 0.9295159578323364]
# [9500, 1.5843089818954468, 48.0]
# Folder already exists, beware of overriding old data!
# [1.4949555206298828, 41.79, 0.8800863027572632]
# [1.4413609633445739, 43.386, 0.9448580741882324]
# [9600, 1.2685469388961792, 52.0]
# Folder already exists, beware of overriding old data!
# [1.5257477021217347, 39.46, 0.8857890963554382]
# [1.4664044322967529, 41.442, 0.9370384216308594]
# [9700, 1.3702577352523804, 46.0]
# Folder already exists, beware of overriding old data!
# [1.45692786693573, 44.7, 0.8762246966362]
# [1.4005856955051421, 46.59, 0.9255501627922058]
# [9800, 1.3049554824829102, 51.0]
# Folder already exists, beware of overriding old data!
# [1.511210836172104, 43.0, 0.8828282952308655]
# [1.4592315242290497, 43.998, 0.9358142614364624]
# [9900, 1.3136717081069946, 46.0]
# Folder already exists, beware of overriding old data!
# [1.5701511001586914, 40.93, 0.8905810117721558]
# [1.5165172548294068, 41.928, 0.9447082877159119]
# [10000, 1.3458181619644165, 51.0]
# checking Hessian
# Folder already exists, beware of overriding old data!
# [1.5607945787906647, 38.57, 0.8880947232246399]
# [1.505319496154785, 39.846, 0.9402465224266052]
# [10100, 1.2641305923461914, 60.0]
# Folder already exists, beware of overriding old data!
# [1.5386193692684174, 40.29, 0.8902440667152405]
# [1.4791843750476836, 41.944, 0.9459026455879211]
# [10200, 1.2997076511383057, 53.0]
# Folder already exists, beware of overriding old data!
# [1.4648062098026275, 44.1, 0.8753640055656433]
# [1.4122063360214234, 46.318, 0.9250504374504089]
# [10300, 1.4014490842819214, 46.0]
# Folder already exists, beware of overriding old data!
# [1.4892860233783722, 41.98, 0.8876705169677734]
# [1.4322883729934692, 43.948, 0.93442302942276]
# [10400, 1.2267022132873535, 56.0]
# Folder already exists, beware of overriding old data!
# [1.5288681495189667, 42.05, 0.8973271250724792]
# [1.468358342409134, 43.676, 0.9370365738868713]
# [10500, 1.5338244438171387, 48.0]
# Folder already exists, beware of overriding old data!
# [1.530179432630539, 40.08, 0.8900189995765686]
# [1.4685677349567414, 41.714, 0.9420077204704285]
# [10600, 1.3551639318466187, 52.0]
# Folder already exists, beware of overriding old data!
# [1.5204631066322327, 40.93, 0.8805063962936401]
# [1.4562712807655334, 42.614, 0.9328422546386719]
# [10700, 1.4281431436538696, 41.0]
# Folder already exists, beware of overriding old data!
# [1.3999070596694947, 47.44, 0.8890088796615601]
# [1.3346087701320648, 49.904, 0.9443687796592712]
# [10800, 1.3385801315307617, 50.0]
# Folder already exists, beware of overriding old data!
# [1.5244984555244445, 42.24, 0.8819113969802856]
# [1.464051524400711, 43.438, 0.9400229454040527]
# [10900, 1.1458884477615356, 54.0]
# Folder already exists, beware of overriding old data!
# [1.5245320010185242, 41.08, 0.8879265785217285]
# [1.459009365081787, 42.876, 0.9454139471054077]
# [11000, 1.4330284595489502, 51.0]
# Folder already exists, beware of overriding old data!
# [1.533253482580185, 38.97, 0.8961142301559448]
# [1.475312659740448, 40.968, 0.9530559778213501]
# [11100, 1.3038630485534668, 57.0]
# Folder already exists, beware of overriding old data!
# [1.6143117666244506, 38.47, 0.8798664212226868]
# [1.5570755846500397, 38.998, 0.9420236945152283]
# [11200, 1.3775248527526855, 50.0]
# Folder already exists, beware of overriding old data!
# [1.3762931680679322, 48.81, 0.912600576877594]
# [1.3071699526309968, 51.482, 0.9553075432777405]
# [11300, 1.2471154928207397, 54.0]
# Folder already exists, beware of overriding old data!
# [1.490223947763443, 41.5, 0.8955577611923218]
# [1.4344829103946686, 43.326, 0.9480175375938416]
# [11400, 1.2780877351760864, 48.0]
# Folder already exists, beware of overriding old data!
# [1.501027581691742, 43.34, 0.8827221393585205]
# [1.4369939212799072, 45.13, 0.9410480856895447]
# [11500, 1.3145695924758911, 57.0]
# Folder already exists, beware of overriding old data!
# [1.5228514099121093, 40.19, 0.8951026797294617]
# [1.463642349243164, 41.814, 0.9544235467910767]
# [11600, 1.3125848770141602, 50.0]
# Folder already exists, beware of overriding old data!
# [1.5416930091381074, 39.25, 0.905518651008606]
# [1.4805926954746247, 40.626, 0.9571103453636169]
# [11700, 1.4199342727661133, 50.0]
# Folder already exists, beware of overriding old data!
# [1.4237538945674897, 45.51, 0.9056174159049988]
# [1.3592415025234224, 47.578, 0.9540718197822571]
# [11800, 1.2977454662322998, 50.0]
# Folder already exists, beware of overriding old data!
# [1.522345427274704, 41.49, 0.9010341167449951]
# [1.457839028596878, 42.63, 0.9534746408462524]
# [11900, 1.1727166175842285, 58.0]
# Folder already exists, beware of overriding old data!
# [1.5211115217208862, 41.67, 0.8976830840110779]
# [1.452997222661972, 42.976, 0.9473422765731812]
# [12000, 1.4554014205932617, 49.0]
# Folder already exists, beware of overriding old data!
# [1.5385420751571655, 40.11, 0.8939703106880188]
# [1.4724938473701477, 41.584, 0.9485747814178467]
# [12100, 1.3240127563476562, 54.0]
# Folder already exists, beware of overriding old data!
# [1.500897890329361, 40.31, 0.8915084600448608]
# [1.4324747502803803, 41.848, 0.9413301348686218]
# [12200, 1.2830455303192139, 52.0]
# Folder already exists, beware of overriding old data!
# [1.4115717601776123, 46.97, 0.8911356925964355]
# [1.341846184015274, 49.302, 0.9436262249946594]
# [12300, 1.3282291889190674, 53.0]
# Folder already exists, beware of overriding old data!
# [1.5019214606285096, 40.87, 0.8846375346183777]
# [1.4408908319473266, 42.126, 0.9345440864562988]
# [12400, 1.3120976686477661, 45.0]
# Folder already exists, beware of overriding old data!
# [1.5212729239463807, 41.68, 0.9091964960098267]
# [1.4549314091205596, 42.972, 0.9526658654212952]
# [12500, 1.3796054124832153, 54.0]
# Folder already exists, beware of overriding old data!
# [1.516772358417511, 39.41, 0.9168506860733032]
# [1.4522885427474976, 41.218, 0.969183623790741]
# [12600, 1.280009150505066, 53.0]
# Folder already exists, beware of overriding old data!
# [1.5298645663261414, 41.25, 0.8946367502212524]
# [1.4552886474132538, 42.606, 0.955982506275177]
# [12700, 1.3724260330200195, 50.0]
# Folder already exists, beware of overriding old data!
# [1.3900337314605713, 47.82, 0.88480144739151]
# [1.3173391811847688, 50.39, 0.9366034269332886]
# [12800, 1.2166798114776611, 58.0]
# Folder already exists, beware of overriding old data!
# [1.4588017570972442, 44.12, 0.8917725086212158]
# [1.3951380772590638, 45.442, 0.9465000033378601]
# [12900, 1.215782642364502, 57.0]
# Folder already exists, beware of overriding old data!
# [1.5550451099872589, 40.9, 0.9007070660591125]
# [1.482001534461975, 42.374, 0.945902407169342]
# [13000, 1.4431709051132202, 52.0]
# Folder already exists, beware of overriding old data!
# [1.5049209654331208, 41.89, 0.9026338458061218]
# [1.4346179962158203, 43.974, 0.9603739380836487]
# [13100, 1.3201004266738892, 55.0]
# Folder already exists, beware of overriding old data!
# [1.4892074429988862, 43.08, 0.888698935508728]
# [1.414336035490036, 44.568, 0.9425597190856934]
# [13200, 1.2240943908691406, 52.0]
# Folder already exists, beware of overriding old data!
# [1.3974021935462952, 47.05, 0.8836399912834167]
# [1.322470261335373, 49.79, 0.941684365272522]
# [13300, 1.1738423109054565, 56.0]
# Folder already exists, beware of overriding old data!
# [1.4358707976341247, 43.96, 0.8968344926834106]
# [1.3644279899597167, 45.86, 0.9523892998695374]
# [13400, 1.1970008611679077, 54.0]
# Folder already exists, beware of overriding old data!
# [1.4566597425937653, 44.39, 0.9095611572265625]
# [1.3785401465892793, 46.626, 0.9549995064735413]
# [13500, 1.3450015783309937, 52.0]
# Folder already exists, beware of overriding old data!
# [1.433084067106247, 42.58, 0.8959481716156006]
# [1.3563916900157929, 45.1, 0.9540376663208008]
# [13600, 1.1883342266082764, 51.0]
# Folder already exists, beware of overriding old data!
# [1.5094558811187744, 41.35, 0.8976282477378845]
# [1.4286200153827666, 42.674, 0.9568210244178772]
# [13700, 1.3056799173355103, 56.0]
# Folder already exists, beware of overriding old data!
# [1.4198775136470794, 46.03, 0.912445604801178]
# [1.33923876953125, 48.534, 0.9574858546257019]
# [13800, 1.0997024774551392, 60.0]
# Folder already exists, beware of overriding old data!
# [1.4095644569396972, 44.71, 0.9082822799682617]
# [1.3322626769542694, 46.712, 0.9561787843704224]
# [13900, 1.1311391592025757, 59.0]
# Folder already exists, beware of overriding old data!
# [1.440587294101715, 44.12, 0.8935679793357849]
# [1.3597410306930542, 46.562, 0.9463159441947937]
# [14000, 1.4350591897964478, 55.0]
# Folder already exists, beware of overriding old data!
# [1.415355213880539, 44.16, 0.9080179929733276]
# [1.3346641352176667, 46.516, 0.963320791721344]
# [14100, 1.2925093173980713, 58.0]
# Folder already exists, beware of overriding old data!
# [1.498746464252472, 42.89, 0.8810317516326904]
# [1.4140287725925444, 44.444, 0.9491288065910339]
# [14200, 1.2519611120224, 50.0]
# Folder already exists, beware of overriding old data!
# [1.3930703675746918, 46.19, 0.8956907391548157]
# [1.3047180597782135, 49.05, 0.9515936374664307]
# [14300, 1.1177688837051392, 63.0]
# Folder already exists, beware of overriding old data!
# [1.4042955434322357, 45.13, 0.8954431414604187]
# [1.3283600642681122, 47.28, 0.9564337730407715]
# [14400, 1.2087191343307495, 53.0]
# Folder already exists, beware of overriding old data!
# [1.4453097343444825, 44.91, 0.9019942879676819]
# [1.3578081383705138, 47.362, 0.9554567933082581]
# [14500, 1.322574496269226, 52.0]
# Folder already exists, beware of overriding old data!
# [1.4406242990493774, 42.94, 0.9028181433677673]
# [1.3549454591274261, 45.256, 0.9546626210212708]
# [14600, 1.2756916284561157, 54.0]
# Folder already exists, beware of overriding old data!
# [1.5108205628395082, 41.67, 0.9010629653930664]
# [1.4222869007587433, 43.154, 0.9589938521385193]
# [14700, 1.2623283863067627, 54.0]
# Folder already exists, beware of overriding old data!
# [1.3932186734676362, 46.74, 0.9020957350730896]
# [1.3074980087280272, 49.534, 0.9533737897872925]
# [14800, 1.1185170412063599, 58.0]
# Folder already exists, beware of overriding old data!
# [1.3986492300033568, 45.06, 0.8961613774299622]
# [1.3190953297615051, 47.616, 0.9511855244636536]
# [14900, 1.2137445211410522, 54.0]
# Folder already exists, beware of overriding old data!
# [1.4560426473617554, 44.3, 0.9039725065231323]
# [1.3721124286651611, 47.006, 0.9599723815917969]
# [15000, 1.3310043811798096, 48.0]
# checking Hessian
# Folder already exists, beware of overriding old data!
# [1.4522830903530122, 43.76, 0.9140873551368713]
# [1.367856570959091, 45.584, 0.9623079895973206]
# [15100, 1.2200114727020264, 60.0]
# Folder already exists, beware of overriding old data!
# [1.498145477771759, 43.06, 0.9174377918243408]
# [1.4091008894443513, 44.416, 0.9664533138275146]
# [15200, 1.26277494430542, 52.0]
# Folder already exists, beware of overriding old data!
# [1.3787412178516387, 47.29, 0.9149348735809326]
# [1.2914855375289918, 50.374, 0.9671438336372375]
# [15300, 1.12937593460083, 59.0]
# Folder already exists, beware of overriding old data!
# [1.3963282442092895, 46.59, 0.9167936444282532]
# [1.3130712592601776, 48.712, 0.9715133905410767]
# [15400, 1.1599836349487305, 59.0]
# Folder already exists, beware of overriding old data!
# [1.4656969392299652, 43.65, 0.9103191494941711]
# [1.3776735014915467, 45.43, 0.959998369216919]
# [15500, 1.306748390197754, 57.0]
# Folder already exists, beware of overriding old data!
# [1.4964908933639527, 41.86, 0.9148067831993103]
# [1.4072996804714202, 43.994, 0.9718979597091675]
# [15600, 1.3479485511779785, 57.0]
# Folder already exists, beware of overriding old data!
# [1.4971844029426575, 41.8, 0.9128825068473816]
# [1.403230605840683, 43.9, 0.9663282036781311]
# [15700, 1.2215640544891357, 53.0]
# Folder already exists, beware of overriding old data!
# [1.3693391835689546, 48.66, 0.9082116484642029]
# [1.280281976222992, 52.074, 0.9571953415870667]
# [15800, 1.0323011875152588, 62.0]
# Folder already exists, beware of overriding old data!
# [1.431288912296295, 43.6, 0.9197366237640381]
# [1.3445656163692474, 45.87, 0.9696595072746277]
# [15900, 1.1562707424163818, 57.0]
# Folder already exists, beware of overriding old data!
# [1.4761829042434693, 44.18, 0.9108113646507263]
# [1.387363793373108, 46.16, 0.9658384323120117]
# [16000, 1.284566044807434, 54.0]
# Folder already exists, beware of overriding old data!
# [1.46231250166893, 42.52, 0.910027801990509]
# [1.3690471851825714, 44.858, 0.9602633118629456]
# [16100, 1.3077850341796875, 57.0]
# Folder already exists, beware of overriding old data!
# [1.4855568253993987, 42.29, 0.9310297966003418]
# [1.3872036006450652, 44.274, 0.9782022833824158]
# [16200, 1.2604233026504517, 55.0]
# Folder already exists, beware of overriding old data!
# [1.3789502966403961, 46.81, 0.9161499738693237]
# [1.2833379373550415, 49.778, 0.969507098197937]
# [16300, 1.0392060279846191, 61.0]
# Folder already exists, beware of overriding old data!
# [1.3818972074985505, 46.85, 0.9088091850280762]
# [1.291631757736206, 49.498, 0.9625232815742493]
# [16400, 1.1324536800384521, 62.0]
# Folder already exists, beware of overriding old data!
# [1.487163738012314, 43.19, 0.9191800355911255]
# [1.39358114528656, 45.032, 0.9726347327232361]
# [16500, 1.3108874559402466, 48.0]
# Folder already exists, beware of overriding old data!
# [1.4754429495334624, 41.7, 0.9225208759307861]
# [1.3794877479076386, 44.114, 0.9779301881790161]
# [16600, 1.2580467462539673, 52.0]
# Folder already exists, beware of overriding old data!
# [1.4931547713279725, 44.43, 0.9390695691108704]
# [1.3951443448066712, 46.086, 0.98073410987854]
# [16700, 1.2709269523620605, 55.0]
# Folder already exists, beware of overriding old data!
# [1.3478832268714904, 49.34, 0.9335775375366211]
# [1.2571383085250853, 53.04, 0.9815488457679749]
# [16800, 1.099544644355774, 65.0]
# Folder already exists, beware of overriding old data!
# [1.37980043053627, 46.39, 0.9372219443321228]
# [1.290110401391983, 49.05, 0.9868993759155273]
# [16900, 1.106266975402832, 60.0]
# Folder already exists, beware of overriding old data!
# [1.4572801768779755, 45.43, 0.9274482727050781]
# [1.3599574105739594, 47.678, 0.9831416606903076]
# [17000, 1.2920018434524536, 49.0]
# Folder already exists, beware of overriding old data!
# [1.4960894453525544, 40.94, 0.9371780753135681]
# [1.4073833031654357, 43.366, 0.9835890531539917]
# [17100, 1.2670470476150513, 52.0]
# Folder already exists, beware of overriding old data!
# [1.4652322697639466, 43.1, 0.9352747201919556]
# [1.3654409639835359, 45.322, 0.9922688603401184]
# [17200, 1.2209190130233765, 48.0]
# Folder already exists, beware of overriding old data!
# [1.397358510494232, 46.81, 0.9320566654205322]
# [1.2928036804199219, 50.378, 0.9852780699729919]
# [17300, 1.0647331476211548, 60.0]
# Folder already exists, beware of overriding old data!
# [1.4119985365867616, 44.59, 0.9244834780693054]
# [1.320813062429428, 47.04, 0.9857661724090576]
# [17400, 1.1037594079971313, 59.0]
# Folder already exists, beware of overriding old data!
# [1.507794576883316, 43.08, 0.9407317042350769]
# [1.4100225760936738, 45.22, 0.9830635190010071]
# [17500, 1.2010802030563354, 56.0]
# Folder already exists, beware of overriding old data!
# [1.5223854088783264, 40.32, 0.9234375357627869]
# [1.4262294952869414, 42.73, 0.9858452081680298]
# [17600, 1.1785694360733032, 56.0]
# Folder already exists, beware of overriding old data!
# [1.4710215485095979, 43.82, 0.9346010684967041]
# [1.3707377517223358, 46.25, 0.991752564907074]
# [17700, 1.21347975730896, 55.0]
# Folder already exists, beware of overriding old data!
# [1.3902886736392974, 47.8, 0.9256104826927185]
# [1.2931286602020264, 51.194, 0.9776337742805481]
# [17800, 1.108250617980957, 58.0]
# Folder already exists, beware of overriding old data!
# [1.3994879186153413, 46.17, 0.9262688159942627]
# [1.3082358729839325, 48.632, 0.9873542189598083]
# [17900, 1.1873483657836914, 62.0]
# Folder already exists, beware of overriding old data!
# [1.4633018589019775, 45.28, 0.9152672290802002]
# [1.3678590607643129, 47.64, 0.972385823726654]
# [18000, 1.282468557357788, 54.0]
# Folder already exists, beware of overriding old data!
# [1.4812239694595337, 42.39, 0.9288070201873779]
# [1.3825260012149811, 44.764, 0.979491114616394]
# [18100, 1.197346806526184, 56.0]
# Folder already exists, beware of overriding old data!
# [1.4769293081760406, 43.13, 0.9241106510162354]
# [1.374621356010437, 45.26, 0.9852159023284912]
# [18200, 1.2286027669906616, 54.0]
# Folder already exists, beware of overriding old data!
# [1.3926067268848419, 48.52, 0.9192504286766052]
# [1.2983955423831939, 51.88, 0.9692481160163879]
# [18300, 1.1680887937545776, 54.0]
# Folder already exists, beware of overriding old data!
# [1.3799136924743651, 46.72, 0.9304339289665222]
# [1.2893790379762649, 49.768, 0.9809793829917908]
# [18400, 1.1828949451446533, 58.0]
# Folder already exists, beware of overriding old data!
# [1.544361709356308, 42.53, 0.9417546391487122]
# [1.4452501678466796, 44.446, 0.9921410083770752]
# [18500, 1.242079734802246, 57.0]
# Folder already exists, beware of overriding old data!
# [1.469616210460663, 42.6, 0.9474115371704102]
# [1.3682384271621704, 45.312, 1.0030837059020996]
# [18600, 1.1347742080688477, 62.0]
# Folder already exists, beware of overriding old data!
# [1.4564721739292146, 44.2, 0.9434430599212646]
# [1.35549849152565, 46.726, 0.9949147701263428]
# [18700, 1.1742421388626099, 58.0]
# Folder already exists, beware of overriding old data!
# [1.4058024561405182, 46.73, 0.9452599287033081]
# [1.2931839923858643, 50.068, 1.0041210651397705]
# [18800, 1.074110507965088, 60.0]
# Folder already exists, beware of overriding old data!
# [1.376273785829544, 47.67, 0.9400398135185242]
# [1.2793347294330597, 50.942, 0.9895721673965454]
# [18900, 1.1647148132324219, 61.0]
# Folder already exists, beware of overriding old data!
# [1.5135438072681426, 43.14, 0.9310299754142761]
# [1.409239487886429, 45.39, 0.992165207862854]
# [19000, 1.2937421798706055, 54.0]
# Folder already exists, beware of overriding old data!
# [1.4371972703933715, 45.11, 0.9483612179756165]
# [1.3354233531951905, 47.692, 1.0045801401138306]
# [19100, 1.2620550394058228, 59.0]
# Folder already exists, beware of overriding old data!
# [1.4617600381374358, 45.94, 0.9434198141098022]
# [1.3523104791641236, 48.366, 0.9960340857505798]
# [19200, 1.2163052558898926, 56.0]
# Folder already exists, beware of overriding old data!
# [1.3554985952377319, 49.61, 0.933368980884552]
# [1.2479040791988374, 53.584, 0.9873672723770142]
# [19300, 1.0965540409088135, 60.0]
# Folder already exists, beware of overriding old data!
# [1.4267584133148192, 44.2, 0.9313609600067139]
# [1.3318641896247865, 46.728, 0.9864360690116882]
# [19400, 1.1492494344711304, 66.0]
# Folder already exists, beware of overriding old data!
# [1.5049314606189728, 43.08, 0.9394711256027222]
# [1.395893435716629, 45.356, 0.9854791164398193]
# [19500, 1.2746961116790771, 57.0]
# Folder already exists, beware of overriding old data!
# [1.4519925463199614, 44.5, 0.9408525228500366]
# [1.346932690858841, 47.432, 1.0018277168273926]
# [19600, 1.2968902587890625, 58.0]
# Folder already exists, beware of overriding old data!
# [1.4577154278755189, 44.72, 0.9291545748710632]
# [1.35949729347229, 47.292, 0.9802172183990479]
# [19700, 1.190527081489563, 55.0]
# Folder already exists, beware of overriding old data!
# [1.4189781606197358, 45.93, 0.9305585026741028]
# [1.311732773065567, 49.068, 0.9840946793556213]
# [19800, 1.0070085525512695, 62.0]
# Folder already exists, beware of overriding old data!
# [1.4043315279483795, 47.06, 0.938275158405304]
# [1.3023236405849457, 50.076, 0.9826681017875671]
# [19900, 0.9868907928466797, 66.0]
# Folder already exists, beware of overriding old data!
# [1.4996796941757202, 44.98, 0.9468958377838135]
# [1.3924307460784913, 47.222, 0.9958710074424744]
# [20000, 1.2933471202850342, 55.0]
# checking Hessian
# Folder already exists, beware of overriding old data!
# eval time 20001
# [1.4184467995166778, 46.05, 0.9404464960098267]
# [1.3124027252197266, 49.33, 0.995201587677002]
# Folder already exists, beware of overriding old data!

# %%
# !zip -r alexnet16.zip /content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet 
from google.colab import files
files.download("/content/alexnet16.zip")
# Out:
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/ (stored 0%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/args.info (deflated 43%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/eigenvalues_step0.pyT (deflated 58%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/eigenvalues_step10000.pyT (deflated 58%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/weight_history.hist (deflated 85%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/eigenvalues_step15000.pyT (deflated 58%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/evaluation_history_TEST.hist (deflated 45%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/tr_outputs.pyT (deflated 12%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/evaluation_history_TRAIN.hist (deflated 39%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/noise_norm_history_TEST.hist (deflated 38%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/eigenvalues_step5000.pyT (deflated 57%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/net.pyT (deflated 12%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/te_outputs.pyT (deflated 12%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/eigenvalues_step20000.pyT (deflated 58%)
# updating: content/results_FC_scales/2_0016_00_cifar10_NLL_alexnet/noise_norm_history_TRAIN.hist (deflated 20%)

# %% [markdown]
# ## alpha is much smaller than 2

# %%
import torch
import numpy as np


evaluation_history_TEST = torch.load(save_dir + '/evaluation_history_TEST.hist')
evaluation_history_TEST = np.array(evaluation_history_TEST)[:-1] # remove the last result,
                                                                 # which is evaluated at the end of training
evaluation_history_TRAIN = torch.load(save_dir + '/evaluation_history_TRAIN.hist')
# evaluation_history_TRAIN.hist saves all evaluation done on the **whole** training set
evaluation_history_TRAIN = np.array(evaluation_history_TRAIN)[:-1]

# %%
# we compute the average of the tail-index measurements for the last 10K iterations
averaged_alpha_TEST = evaluation_history_TEST[-10000//eval_freq:,-1].mean() 
averaged_alpha_TRAIN = evaluation_history_TRAIN[-10000//eval_freq:,-1].mean() 

print('averaged alpha (test): %f'%averaged_alpha_TEST)
print('averaged alpha (train): %f'%averaged_alpha_TRAIN)
# Out:
# averaged alpha (test): 0.911899
# averaged alpha (train): 0.964972

# %% [markdown]
# ## Show it's heavily tailed

# %%
noise_norm_history_TRAIN = torch.load(save_dir + '/noise_norm_history_TRAIN.hist')
noise_norm_history_TRAIN = np.array(noise_norm_history_TRAIN)[:-1] 
normgrad = np.reshape(noise_norm_history_TRAIN, (-1))

fig,ax=plt.subplots(1,2,figsize=(10,5))
ax[0].hist(normgrad, bins=100)
ax[0].set_yscale('log')
ax[0].set_title('Real')
gaussian = np.random.normal(loc=0.8, scale=0.5, size=1000000)
ax[1].hist(gaussian, bins=100)
ax[1].set_yscale('log')
ax[1].set_xlim([0,4])
ax[1].set_title('Gaussian')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-54f0c2995f58> in <module>()
#       1 noise_norm_history_TRAIN = torch.load(save_dir + '/noise_norm_history_TRAIN.hist')
# ----> 2 noise_norm_history_TRAIN = np.array(noise_norm_history_TRAIN)[:-1]
#       3 normgrad = np.reshape(noise_norm_history_TRAIN, (-1))
#       4
#       5 fig,ax=plt.subplots(1,2,figsize=(10,5))
#
# ValueError: only one element tensors can be converted to Python scalars

# %% [markdown]
# ## At the end of training, it ends up in a flat and wide region with most eigenvalues close to 0
#
# - But there are several large Hessian outliers.
# - loss are plotted to prove the model has been "resting" here for quite a while

# %%
# check the Hessian
density_eigen, density_weight = torch.load(save_dir + '/eigenvalues_step20000.pyT')
from density_plot import get_esd_plot # ESD plot
get_esd_plot(density_eigen, density_weight)
plt.axvline(0,c='k')
plt.show()

# %%
# show loss plot to prove the model has been "resting" here for quite a while
sub, up = close_check_lb//close_check_freq, close_check_lb//close_check_freq+(close_check_hb-close_check_lb)//close_check_freq
xtrain = list(range(0,iter+eval_freq,eval_freq))

loss_early_TRAIN = evaluation_history_TRAIN[:,1].copy()
loss_early_TRAIN = np.concatenate((loss_early_TRAIN[:sub],loss_early_TRAIN[sub:up:100],loss_early_TRAIN[up:]))
plt.plot(xtrain,loss_early_TRAIN)

# %% [markdown]
# ## wanna show the escape from the local minimum
#
# - Not yet successful

# %%
import matplotlib.pyplot as plt

# we record the dynamics of the tail-index measurements for the first 10k iterations
# alpha_early_TEST = evaluation_history_TEST[:,-1].copy()
alpha_early_TRAIN = evaluation_history_TRAIN[:,-1].copy()
# and loss and accuracy
# accuracy_early_TEST = evaluation_history_TEST[:,-2].copy()
# loss_early_TEST = evaluation_history_TEST[:,1].copy()
# loss_early_TEST[117] = (loss_early_TEST[116]+loss_early_TEST[118])/2 # wird point..
# accuracy_early_TEST[117] = (accuracy_early_TEST[116]+accuracy_early_TEST[118])/2 # wird point..
accuracy_early_TRAIN = evaluation_history_TRAIN[:,-2].copy()
loss_early_TRAIN = evaluation_history_TRAIN[:,1].copy()

### there is a part during training
### where I recorded statistics every 10 iters (instead of 100)
### we can either smooth
# def smooth(y, box_pts):
#     box = np.ones(box_pts)/box_pts
#     y_smooth = np.convolve(y, box, mode='valid')
#     return y_smooth

# N = 9
sub, up = close_check_lb//close_check_freq, close_check_lb//close_check_freq+(close_check_hb-close_check_lb)//close_check_freq
# alpha_early_TRAIN[sub+N//2:up-N//2] = smooth(alpha_early_TRAIN[sub:up],N)
# alpha_early_TEST[sub+N//2:up-N//2] = smooth(alpha_early_TEST[sub:up],N)
# accuracy_early_TRAIN[sub+N//2:up-N//2] = smooth(accuracy_early_TRAIN[sub:up],N)
# accuracy_early_TEST[sub+N//2:up-N//2] = smooth(accuracy_early_TEST[sub:up],N)
# loss_early_TRAIN[sub+N//2:up-N//2] = smooth(loss_early_TRAIN[sub:up],N)
# loss_early_TEST[sub+N//2:up-N//2] = smooth(loss_early_TEST[sub:up],N)

### or sample
sample_step = 100//10
alpha_early_TRAIN = np.concatenate((alpha_early_TRAIN[:sub],alpha_early_TRAIN[sub:up:sample_step],alpha_early_TRAIN[up:]))
accuracy_early_TRAIN = np.concatenate((accuracy_early_TRAIN[:sub],accuracy_early_TRAIN[sub:up:sample_step],accuracy_early_TRAIN[up:]))
loss_early_TRAIN = np.concatenate((loss_early_TRAIN[:sub],loss_early_TRAIN[sub:up:sample_step],loss_early_TRAIN[up:]))


fig, ax = plt.subplots(3,1,figsize=(16,8),sharex=True)
# !!!xaxis is not correct yet!!!
# xtest = list(range(0,900,100))+list(range(900,2000,10),)+list(range(2000,11100,100))
xtrain = list(range(0,20100,100))
# xtrain = list(range(0,900,100))+list(range(900,2000,10),)+list(range(2000,11100,100))
# xtrain = list(range(0,(len(alpha_early_TRAIN))*eval_freq, eval_freq))
ax[0].plot(xtrain,alpha_early_TRAIN, label='train')
# ax[0].plot(xtest,alpha_early_TEST, label='test')
ax[0].legend()
ax[0].set_title('Estimated alpha')
ax[1].plot(xtrain,accuracy_early_TRAIN)
# ax[1].plot(xtest,accuracy_early_TEST)
ax[1].set_title('Accuracy %')
ax[2].plot(xtrain,loss_early_TRAIN)
# ax[2].plot(xtest,loss_early_TEST)
ax[2].set_title('loss')
ax[0].set_xscale('log')
